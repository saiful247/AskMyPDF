# %%
import os
import faiss
import pickle
import google.generativeai as genai
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import FAISS
from langchain.chains import RetrievalQAWithSourcesChain
from langchain_google_genai import ChatGoogleGenerativeAI, GoogleGenerativeAIEmbeddings
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
google_api_key = os.getenv("GOOGLE_API_KEY")

# %%
llm=ChatGoogleGenerativeAI(model="gemini-2.0-flash",temperature=0.7)

# %%
docs_folder='C:/Users/saifu/Desktop/rag_project1/docs'
pdf_files = [os.path.join(docs_folder,f) for f in os.listdir(docs_folder) if f.endswith('.pdf')]
documents=[]

for pdf in pdf_files:
    loader=PyPDFLoader(pdf)
    documents.extend(loader.load())

# %%
len(documents)
# Out:
# 420

# %%
documents
# Out:
# [Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 0, 'page_label': '1'}, page_content='Software Process Modeling\nSLIIT  - Faculty of Computing\nSoftware Process Model\n2021\nIntroduction'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 1, 'page_label': '2'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nSession outcomes\n•Introduction to Module\n•SPM- Introduction\nSLIIT 2'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 2, 'page_label': '3'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nAcademic Integrity Policy\n• Are you aware that following are not accepted in \nSLIIT???\n• Plagiarism - using work and ideas of other individuals \nintentionally or unintentionally \n• Collusion - preparing individual assignments together and \nsubmitting similar work for assessment. \n• Cheating - obtaining or giving assistance during the course of \nan examination or assessment without approval\n• Falsification – providing fabricated information or making use \nof such materials\n• Committing above offenses come with serious \nconsequences !\n• See General support section of Courseweb for full \ninformation.\nEnrollment Key :IT1060 for 2021 Feb'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 3, 'page_label': '4'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nProgression Criteria\n• In order to progress from one academic year to the next, \nyou must maintain the following minimum academic \nstandard.\n• From year 1 to year 2 – No more than 5 failed or incomplete \nmodules\n• From year 2 to year 3 – No more than 3 failed or incomplete \nmodules\n• From year 3 to year 4 – No more than 2 failed or incomplete \nmodules\n• If you do not meet the above criteria, you will not be able to \nprogress to the next year.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 4, 'page_label': '5'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nMODULE INTRODUCTION\nSLIIT 5'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 5, 'page_label': '6'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nModule contents\n• Course web - SPM-IT1060\n• IT1060 [2021/FEB] General\n• Module outline\n• Notices\n• Marks\n• Weekly updates\n• Lecture\n• Lab\n• Tutorial\n• Additional Reading/Recordings \nSLIIT 6'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 6, 'page_label': '7'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nLearning outcomes\nSLIIT 7\nDifferentiate the characteristics and effects of different types of software \nengineering processes.\nDescribe the requirement engineering process and components of a \nformal requirements document for a software project. \nApply the knowledge of UML to model and represent system \nrequirements. \nDescribe software design strategies and the importance of design models.\nApply the knowledge of software implementation and testing to write \ntest cases.\nApply Agile development methodology.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 7, 'page_label': '8'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nAssessment Criteria\nMid Term Examination 30%  LO1-LO4\nAssignment I 10% LO3-LO5\nAssignment II 10% LO4-LO5\nFinal Examination 50% LO1-LO9\nTo pass this module, students need to obtain a pass mark in\nboth “Continuous Assessments” and “End of the Semester\nExamination” components which would result in an overall\nmark that would qualify for a “C” grade or above.\nSLIIT 8'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 8, 'page_label': '9'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nAssignments\n•Five members in one group\n•Randomly chosen case study\n•Two submissions\n•Before Mid term – Week 7\n• Based  on requirements engineering and use \ncase diagrams\n•After Mid term – Week 12\n• Based on Activity Diagram\nSLIIT 9'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 9, 'page_label': '10'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nRecommendTexts\n\uf0b7 Ian Sommerville, “Software Engineering”, Pearson Education\nLimited, 10th edition, 2016\n\uf0b7 R. Pressman, “Software Engineering: a practitioner’s approach”,\nMcGraw-Hill Education; 8th edition, 2014\n\uf0b7 K.S. Rubin, Essential Scrum: A Practical Guide to the Most Popular\nAgile Process, Addison-Wesley, 2012\n\uf0b7 SWEBOK, Guide to the Software Engineering Body of Knowledge, 2014'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 10, 'page_label': '11'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nLab Schedule\nSLIIT 11'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 11, 'page_label': '12'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nSPM- INTRODUCTION\nSLIIT 12'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 12, 'page_label': '13'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nSession Outcomes\n1. What is a Software\n2. What is Software Engineering\n3. Software Process\n4. Software Process Activities\n5. Software process model\n6. Software Development Life Cycle\n7. Software Engineering Ethics'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 13, 'page_label': '14'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nWhat is Software?\nSoftware is not only the computer programs, but \nalso  associated documentation and configuration \nfiles,  needed to make the programs operate \ncorrectly.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 14, 'page_label': '15'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nPopular Software'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 15, 'page_label': '16'}, page_content='SLIIT  - Faculty of Computing\nIT1060\n1st Year 1st Semester IP \n• Are these Software ?\n• What are things that you need to do to \ndevelop Software?'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 16, 'page_label': '17'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nLibrary Software\nhttp://www.verussolutions.biz/technology.php'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 17, 'page_label': '18'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nPrograms Vs. Software Products\nProgram\n• Small\n• Single developer\n• Small in size\n• Limited Functionality\n• Single user (author)\n• Simple user interface\n• Sparse documentation\n• No user manual\n• Ad hoc development\nSoftware Product\n• Large\n• Team of developers\n• Multiple users \n(customer)\n• Complex user interfaces\n• Detailed documentation\n• User manual\n• Systematic development\nSLIIT 18'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 18, 'page_label': '19'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nMS Teams'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 19, 'page_label': '20'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nMS Teams'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 20, 'page_label': '21'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nTeamsDocumentation'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 21, 'page_label': '22'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nSoftware products can be\n•Generic\n•These are stand alone systems that are \nproduced by a development organization \nand sold on the open market to any \ncustomer who is able to buy them.\n•Customized\n•These are systems that are developed for \na particular customer requirements'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 22, 'page_label': '23'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nHow do we develop a real software?\n• There will be a real user (Customer) who would need \nto use the software.\n1. Feasibly study (whether it is technical feasible and \nfinancially worthwhile)\n2. You have to find out what the customer wants \n(Requirements Gathering)\n3. Analyze the problem\n4. Develop a solution (Design)\n5. Code the solution\n6. Test and Debug\n7. Maintenance\nSLIIT 23'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 23, 'page_label': '24'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nSuggest Something Innovative?\n•Suggest your dream software\n•Do not think about technical barriers\n•You can think beyond of the reality\n“New Ideas will lead you to highest \npoint of the Software Engineering”'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 24, 'page_label': '25'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nSoftware Engineering\n\uf0a7IEEE Definition of Software Engineering:\nThe application of a systematic, disciplined, \nquantifiable approach to the development, operation, \nand maintenance of software;\nthat is, the application of engineering to software.\nIEEE Standard 610.12-1990, 1993.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 25, 'page_label': '26'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nSoftware Engineering Cont.\n• Engineering discipline\nmake things work by applying theories, methods and\ntools where these are appropriate and also try to\ndiscover solutions to problems even when there’s no\nproper theories/methods.\n• All aspects of software production \nNot only technical processes of software\ndevelopment, but also project management and\ndevelopment of tools, methods and theories to support\nS/W production.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 26, 'page_label': '27'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nKey Challenges\n•Deliver  Quality software to the \ncustomer at the agreed time\n•The product is intangible\n•Software processes are available \nand organization/product specific\n•Keep overall costs within budget'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 27, 'page_label': '28'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nProcess'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 28, 'page_label': '29'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nMaking A Cup of Tea'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 29, 'page_label': '30'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nMaking A Cup of Tea \n• Ingredients : Tea Leaves, Sugar, Milk Powder, Boiled Water\n• Process \nBoil the water\nPour boiled water into cup\nPut a tea bag inside a cup\nLeave it few minutes\nPut Sugar and Milk (if necessary)\nStir few seconds\nArrange it nicely\n• Output: Tea'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 30, 'page_label': '31'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nSoftware Process\n•A software process is a set of \ninterrelated activities and tasks that \ntransform input work products into \noutput work products. (SWEBOK V3 \n– Chapter 8)'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 31, 'page_label': '32'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nSoftware Process Activities\n•Software Specification\n•Software Development\n•Software Validation\n•Software Evolution'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 32, 'page_label': '33'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nSoftware Process Activities\n•Software Specification\n• The functionality of the software and constraints\n•Software Development\n• The software is designed and programmed. \n•Software Validation\n• The software must be validated \n•Software Evolution\n• The software must evolve'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 33, 'page_label': '34'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nSoftware Processes\n“There is no universal process that is \nright for all kinds of software”\nEx:\n• For safety-critical systems, a very structured\ndevelopment process is required where detailed\nrecords are maintained.\n• For business systems, with rapidly changing\nrequirements, amore flexible ,agile process is likely\nto be better'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 34, 'page_label': '35'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nSoftware process model\n• It is a simplified representation of software process.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 35, 'page_label': '36'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nSoftware Development Life Cycle'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 36, 'page_label': '37'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nSoftware Development Life Cycle \nModels \n•A Software Development Life Cycle Model\n•has a series of stages that a software \nproduct undergoes during its life time.\n•is a descriptive and diagrammatic \nrepresentation of the software life cycle.\n•is often referred as software process model.\n•maps the basic development activities to \nphases in different ways'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 37, 'page_label': '38'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nGeneral Software Process Models\n• Waterfall Model \n• Classic\n• Iterative\n• Prototyping\n• Evolutionary Model\n• Incremental\n• Spiral\n• Agile development.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 38, 'page_label': '39'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nSoftware Engineering Ethics\nAs a Professional Software Engineer,\n• You should accept  that your work involves wider \nresponsibility than simply application of technical \nskills\n• You should behave in an ethical way  and morally \nresponsible way\n• You should not use your skills and abilities to \nbehave in a dishonest way that will bring disrepute \nto the software engineering profession'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 39, 'page_label': '40'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nSoftware Engineering Ethics Con.\nStandards\n• Confidentiality\n• Competence\n• Intellectual Property rights\n• Computer misuse'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 40, 'page_label': '41'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nCase Studies \n• Library Management System'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 41, 'page_label': '42'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nLibrary Management System\n• Sri Lanka Institute of Information Technology (SLIIT) is the\nlargest degree awarding institute in Sri Lanka with degree\nprograms diversified to computing, business and\nengineering. In order to cater to its growing need of\nknowledge the institute maintains a Library Information\nSystem connecting Malabe, Metropolitan and Matara\ncampuses. Each holds a latest collection of books and\nperiodicals, particularly in the field of Information\nTechnology, business management, engineering, general\nEnglish, architecture and quantity surveying. The library of\nthe Malabe Campus acts as the main resource center\nthrough which all library development activities are\ncoordinated. SLIIT libraries are open to SLIIT students daily\nincluding weekends from 7.30 AM to 7.00 PM.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 42, 'page_label': '43'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nTasks carried out at the library\n• Add library materials\n• Manage Library membership\n• borrow books\n• return books\n• Pay fine on overdue materials\n• Refund library deposit\n• Replace lost library material\n• Search library materials\n• Generate reports'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 43, 'page_label': '44'}, page_content='SLIIT  - Faculty of Computing\nIT1060\nNext Lecture\nSoftware \nDevelopment Life \nCycle Models'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 44, 'page_label': '45'}, page_content='IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nSOFTWARE PROCESS MODELING\nSoftware Development Life Cycles\n1'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 45, 'page_label': '46'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nSession Outcomes\n• What is a \n• Software Process\n• SDLC\n• Life Cycle Model\n• Life Cycle Models\n• Waterfall Model\n• Prototyping Model\n• Incremental Model\n• Spiral Model\n• Comparison and Selection'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 46, 'page_label': '47'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nWhat is an Engineering Process?\nSLIIT 3'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 47, 'page_label': '48'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nWhat is a Software Development \nProcess?\n• A set of Activities and Associated Results that produce a \nSoftware.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 48, 'page_label': '49'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nFundamental Process Activities\n1. Software Specification\n2. Software Development \n3. Software Validation \n4. Software Evolution\nSLIIT 5'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 49, 'page_label': '50'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\n1. Software Specification\n• Specification involves clearly documenting \nthe expectations on the system to be built\n• Lays out requirements, and may include \nwritten and diagrammatic description of \nthe services that the future system must \nprovide.\nSLIIT 6'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 50, 'page_label': '51'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\n2. Software Development\n• Software development involves designing \nand implementing the system according \nto the software specification\nSLIIT 7'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 51, 'page_label': '52'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\n3. Software Validation\n• Software validation involves checking and \nverifying whether the system fulfills the \nrequirements. \nSLIIT 8'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 52, 'page_label': '53'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\n4. Software Evolution\n• Software needs to be changed and \nupgraded with time.\nSLIIT 9'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 53, 'page_label': '54'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nWhat is a SDLC?\n• The Software \nDevelopment Life Cycle \n(SDLC) is a framework that \ndefines activities \nperformed throughout \nthe software development \nprocess'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 54, 'page_label': '55'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nLife Cycle Model (Process Model)\n• A software life cycle (process) model:\n• is a descriptive and diagrammatic model \nof the life cycle of a software product;\n• identifies all the activities and phases \nnecessary for software development;\n• establishes a precedence ordering among \nthe different activities.\n• Life cycle models encourage systematic \nand disciplined software development.\nSLIIT 11'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 55, 'page_label': '56'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nLife Cycle Models\n• Traditional Approaches\n1. Waterfall Model\n2. Incremental Model\n3. Prototyping Model\n4. Spiral Model\n5. Unified Process\n• Modern Approaches\n• Agile Methods (XP , Scrum)\n• Secure Software Development'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 56, 'page_label': '57'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nLife Cycle Models'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 57, 'page_label': '58'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nWaterfall Model \n1'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 58, 'page_label': '59'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nWaterfall Model'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 59, 'page_label': '60'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nWaterfall model\n• Waterfall model is the most well known software \nlifecycle development model. \n• It is very simple to understand and use. \n• Each phase begins only after the previous phase is \nover. \n• Also called Linear Model\n• This model specifies what the system is supposed \nto do (i.e. define the requirements) before building \nthe system (i.e. designing)'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 60, 'page_label': '61'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\n1. Feasibility Study\n• This is the first phase of any SDLC model.\n• The project objective is determined during this phase. \n• The client and company developing the software \ndecide if they should ;\n• Keep the existing system as is, or \n• Build a new software'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 61, 'page_label': '62'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nWhy do a feasibility study?\n• To provide management with enough information \nto know:\n• Whether the project can be done\n• Whether the final product will benefit its users\n• What the alternative solutions are \n• Whether there is a preferred alternative'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 62, 'page_label': '63'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nExample –Library System\n• What are the feasibility criteria for a ‘Library \nSystem’?'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 63, 'page_label': '64'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\n2. The Requirements Phase\n• Aim: to understand the customer’s \nrequirements:\n• A customer may be a single person, a group, \na department, or an entire organization:\n• This phase involves two distinct activities:\n1. Requirements Gathering  and \nRequirements Analysis\n2. Requirements Specification\nSLIIT 20'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 64, 'page_label': '65'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\n2a.1 Requirement Gathering\n• The goal of this phase is for the stakeholders to find out \nthe ‘what to be done’. \n• Questions answered during this phase include:\n• Who will use the system?\n• How will they use the system?\n• What will be the input for the system?\n• What will be the output from the system?\n• Requirement Gathering involve collecting information \nthrough meetings, interviews and discussions'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 65, 'page_label': '66'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\n2a.2 Requirements Analysis\n• Aim: To understand exactly what the customer  \nneeds.. which may not be what they ask for:\n• data to be input to the system;\n• processing to be performed on these data;\n• data to be output from the system;\n• characteristics of the system as a whole;\n• constraints on the system/project.\n• WHAT, not HOW!\nSLIIT 22'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 66, 'page_label': '67'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\n2b Requirements Specification\n• Requirements are documented in a \nSoftware Requirements Specification (SRS).\n• The SRS forms the basis of a legal contract \nwith the customer:\n• Software Engineers who specialize in \nrequirements gathering, analysis, and \nspecification are called (Systems/ Business / \nRequirement) Analysts.\nSLIIT 23'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 67, 'page_label': '68'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\n3. Design\n• Architects and Designers craft a high-level \nand low level design of the software. \n• Architectural Design\n• Low level Design \n• Decisions are made about hardware, \nsoftware and the system architecture. \n• A design specification document (DSD) \nrecords this information.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 68, 'page_label': '69'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\n4. Development\n• On receiving system design \ndocuments, the work is divided \nin modules. \n• A set of developers code the \nsoftware as per the established \ndesign specification, using a \nchosen programming language\n• Programmers carry out some \nprogram testing to discover \nfaults in the program and \nremove these faults in the \ndebugging process'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 69, 'page_label': '70'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\n5. Testing\n• The testing phase ensures that the software\nrequirements are in place and that the software works\nas expected.\n• When a defect is identified, testers inform the\ndevelopers.\n• If the defect is valid, developers resolve it and create a\nnew version of the software which then repeats the\ntesting phase.\n• The cycle continues until all defects are mitigated and\nthe software is ready for deployment into the\nproduction environment.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 70, 'page_label': '71'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\n6. Deployment and Maintenance. \n• Once the software is error free, it is\ndeployed into the operating\nenvironment.\n• While the customers are using the\nsoftware, any issues will be brought to\nthe attention of the maintenance team\n• They work to resolve them immediately.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 71, 'page_label': '72'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nWaterfall in practise'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 72, 'page_label': '73'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nWaterfall Model - Strengths\n• Simple and easy to manage– each\nphase has specific deliverables.\n• Milestones are better understood\n• Sets requirements stability\n• Works well for smaller projects where\nrequirements are very well understood.\n• A schedule can be set with deadlines.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 73, 'page_label': '74'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nWaterfall Model - Weaknesses\n• No working software is produced until end.  \n• High uncertainty.  \n• Delays discovery of serious errors.\n• After requirements phase, there is no formal \nway to make changes to the requirements.  \n• Not a good model for \n• complex projects\n• projects where requirements are at a moderate to high risk \nof changing'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 74, 'page_label': '75'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nWhen to use Waterfall Model\n• Software requirements clearly defined and \nknown\n• Product definition is stable\n• New version of the existing software system is \ncreated\n• Software development technologies and tools \nare well known\n• Ample resources with required expertise are \navailable'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 75, 'page_label': '76'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\n2\nIterative Model'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 76, 'page_label': '77'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nIterative Waterfall Model \n• The classical waterfall model is idealistic:\n• It assumes that no defects are introduced during \nany of the development phases.\n• In practice, defects are introduced during every \nphase of the software life cycle:\n• Hence feedback paths must be added to the \nclassical waterfall model.\n• The resulting Iterative Waterfall Model is one of \nthe most widely used process models….\nSLIIT 33'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 77, 'page_label': '78'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nIterative Waterfall Mode\nSLIIT 34'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 78, 'page_label': '79'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nIterative Waterfall Model\n•Strengths\n• Defects are detected and fixed early \nthrough the feedback path\n•Weaknesses\n• Limited customer interactions\n• Difficult to incorporate change requests\nSLIIT 35'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 79, 'page_label': '80'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\n3\nIncremental Model'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 80, 'page_label': '81'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nIncremental model \n• Incremental model is an evolution of waterfall\nmodel.\n• The product is designed, implemented, integrated and\ntested as a series of incremental builds.\n• The incremental model prioritizes requirements of\nthe system and then implements them in groups.\n• It is the process of constructing a partial\nimplementation of a total system and slowly\nadding increased functionality or performance.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 81, 'page_label': '82'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nIncremental model'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 82, 'page_label': '83'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nIncremental model - Strengths \n• Generates working software quickly and early\nduring the software life cycle.\n• More flexible - less costly to change scope and\nrequirements.\n• Easier to test and debug.\n• Easier to manage risk.\n• Lowers initial delivery cost.\n• Less stress for the development team.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 83, 'page_label': '84'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nIncremental model - Weaknesses\n• Requires good planning and design\n• Demarcation of increments can be difficult in a \npractical application.\n• Each phase of an iteration is rigid and do not \noverlap each other. \n• Total cost of the system might not be lower. \n• Problems may arise pertaining to system \narchitecture because not all requirements are \ngathered up front for the entire software life cycle.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 84, 'page_label': '85'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nWhen to use Incremental model\n• On projects which have lengthy \ndevelopment schedules \n• A need to get basic functionality to the \nmarket early \n• Most of the requirements are known up-\nfront but are expected to evolve over time \n• On a project with new technology'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 85, 'page_label': '86'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nMini-Case 1\n• The project is to develop an inventory control\nsystem for a new super market in town. It should\nhave all the regular functionalities such as adding\nnew stocks, getting reports such as inventory re-\norder report and daily sales report etc. A project\nteam has previous experience developing inventory\nsystems for other clients.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 86, 'page_label': '87'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\n4\nPrototyping Model'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 87, 'page_label': '88'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nPrototype Model\n• Instead of freezing the requirements before\ncoding or design, a prototype is built to clearly\nunderstand the requirements.\n• This prototype is built based on the current\nrequirements.\n• Through examining this prototype, the client gets\na better understanding of the features of the final\nproduct.\n• Requirements may be changed with the client\nfeedback on the prototype.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 88, 'page_label': '89'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nPrototype Model'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 89, 'page_label': '90'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nPrototyping Model - Strengths\n•Ability to clarify user’s expectations \nfor the system to be developed\n•Prototype stimulates awareness of \nadditional needed functionality\n•Better user satisfaction\n•Early user feedback'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 90, 'page_label': '91'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nPrototyping Model - Weaknesses\n• Scope Creep - The system scope may \nexpand beyond original plans. \n• Overall maintainability may be \noverlooked. \n• The customer may want the prototype \nbe delivered. \n• Process may continue forever'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 91, 'page_label': '92'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nWhen to Use Prototyping\n• Requirements are unstable or have to \nbe clarified \n• Many user interfaces \n• New technology\n• New, original development\n• Developers are not familiar with the \ntechnical and development tools'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 92, 'page_label': '93'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nSelection of Approach\nRequirements \nDefined?\nEarly \nRelease?\nIncremental\nWaterfall\nPrototyping\nYES\nNO\nYES\nNO'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 93, 'page_label': '94'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nQuestion\n• A company is developing an advanced version of \ntheir current software available in the market, what \nmodel approach would they prefer ?\na) Waterfall\nb) Incremental\nc) Prototyping'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 94, 'page_label': '95'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nQuestion\nSelection of a model is based on…?\na) Requirements\nb) Development team\nc) Users\nd) Project type and associated risk\ne) All of the mentioned'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 95, 'page_label': '96'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\n5\nSpiral Model'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 96, 'page_label': '97'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nSpiral Model \n• Meta Model - combines iterative and \nprototype development with the systematic, \ncontrolled aspects of the waterfall model. \n• Allows for incremental releases\n• Introduced by Barry Boehm in 1986.\n• Allows elements of the product to be added \nin when they become available or known. \n• Emphasises on risk management'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 97, 'page_label': '98'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nSpiral Model'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 98, 'page_label': '99'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nSpiral Model \n• Quadrant 1: Planning\n• Determine objectives, alternatives, and \nconstraints. \n• Quadrant 2: Risk Analysis\n• Evaluate alternatives, identify, resolve risks. \n• Quadrant 3: Development & Test\n• Develop, verify, next-level product. \n• Quadrant 4: Evaluation\n• Analyse feedback and plan next phases.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 99, 'page_label': '100'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nSpiral Model'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 100, 'page_label': '101'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nQuestion\n• Which of the following models will not be able to \ngive the desired outcome if user’s participation is \nnot involved?\na) Waterfall\nb) Spiral\nc) Prototyping'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 101, 'page_label': '102'}, page_content='SLIIT  - Faculty of Computing\nIT 1060\nSpiral Model - Strengths \n• Focus on risk analysis. \n• Good for large and mission critical \nprojects \n• A working software is produced early \n• The design does not have to be perfect \n• Early and frequent feedback from users\n• Cumulative costs assessed frequently'),
# ...
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 387, 'page_label': '388'}, page_content='IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nActivity\n1. An Agile team ...\na) Is self - organizing, with each member having the \nsame technical skills.\nb) Collaborates and supports its team members \nc) Ensures that weak members of the team are \nallocated the simpler tasks\nd) Ensures blame is allocated fairly'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 388, 'page_label': '389'}, page_content='IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nSCRUM Artifacts\n• Product Backlog\n• Sprint Backlog\n• Burn down Charts'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 389, 'page_label': '390'}, page_content='IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nProduct Backlog\n28'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 390, 'page_label': '391'}, page_content='IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nCreating the product \nbacklog• There are many ways to store the product \nbacklog:\n– As a collection of index cards or post-its on the wall\n– On a flip-chart\n– In a requirements management tool\n– In Excel'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 391, 'page_label': '392'}, page_content='IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nActivity\n1. Who is responsible for prioritizing the \nproduct backlog?\na) Product Owner\nb) SCRUM Master\nc) Lead Developer\nd) End Customer'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 392, 'page_label': '393'}, page_content='IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nSprint and Sprint \nBacklog\n• An iteration in a Scrum project is known as a \nSprint.\n• Before starting a Sprint the Team should come \nup with a Sprint backlog. \n• The sprint backlog (release backlog) is a list of \nuser stories identified by the Scrum team to be \ncompleted during the sprint. \n• This is a subset of Product backlog user stories \ndefined only for a particular sprint.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 393, 'page_label': '394'}, page_content='IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nSprint Backlog'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 394, 'page_label': '395'}, page_content='IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nActivity\n1. Who is responsible for all estimates of the \nProduct Backlog items?\na) The Product Owner\nb) The Development Team\nc) The Scrum Master\nd) The Scrum Team'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 395, 'page_label': '396'}, page_content='IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nSprint Burn Down Chart\n– A burn down chart is a graphical representation \nof work left to do vs time. \n– The outstanding work (or backlog) is often on \nthe vertical axis, with time along the horizontal. \n– That is, it is a run chart of outstanding work. It is \nuseful for predicting when all of the work will \nbe completed.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 396, 'page_label': '397'}, page_content='IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nSprint Burn Down Chart'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 397, 'page_label': '398'}, page_content='IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nActivity\n1. What is the Scrum Master responsible for?\na) Ensuring the Scrum Team adheres to Scrum \ntheory, practices, and rules\nb) Ensuring the Product Backlog is visible, \ntransparent, and clear to all\nc) Ensuring the Development Team understands \nitems in the Product Backlog to the level \nneeded \nd) Ensuring Scrum is understood and enacted'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 398, 'page_label': '399'}, page_content='IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nScrum Activities'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 399, 'page_label': '400'}, page_content='IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nSprint Planning\n– Each Sprint may be considered a project with no\nmore than a one-month horizon.\n– Like projects, Sprints are used to accomplish\nsomething. Each Sprint has a definition of what is\nto be built, a design and flexible plan that will\nguide building it, the work, and the resultant\nproduct.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 400, 'page_label': '401'}, page_content='IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nSprint Planning Meeting\n– The work to be performed in the Sprint is\nplanned at the Sprint Planning, its a\ncollaborative work of the entire Scrum Team.\n– Time-boxed to a maximum of eight hours for a\none-month Sprint.\n– Sprint Planning answers the following:\n• What can be delivered in the Increment resulting\nfrom the upcoming Sprint?\n• How will the work needed to deliver the Increment\nbe achieved?'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 401, 'page_label': '402'}, page_content='IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nDaily Scrum'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 402, 'page_label': '403'}, page_content='IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nDaily SCRUM\n– Short (15 min) frequent meetings, facilitated\nby the Scrum Master.\n– One activity – Scrum Master asks each\nattendee 3 questions.\n1. What have you completed (relative to the Backlog)\nsince the last Scrum meeting?\n2. What got in your way of completing this work?\n3. What will you do between now and the next Scrum\nmeeting?'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 403, 'page_label': '404'}, page_content='IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nSprint Review'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 404, 'page_label': '405'}, page_content='IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nSprint Review\n– Sprint Review is held at the end of the Sprint to\ninspect the Increment and adapt the Product\nBacklog if needed.\n– ANYTHING can be changed, work can be added,\neliminated, reprioritized.\n– 4 hour time boxed meeting for a 1 month sprint.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 405, 'page_label': '406'}, page_content='IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nSprint Retrospective'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 406, 'page_label': '407'}, page_content='IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nSprint Retrospective\n• The Sprint Retrospective occurs after \nthe Sprint Review and prior to the \nnext Sprint Planning.\n– Three-hour time-boxed meeting for one-month \nSprint.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 407, 'page_label': '408'}, page_content='IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nActivity\n1. When is the work planned for the first days \nof a Sprint decomposed?\na) At the end of Sprint Review\nb) At the end of Sprint Planning\nc) At the first Daily Scrum\nd) At the beginning of Sprint Retrospective'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 408, 'page_label': '409'}, page_content='IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 409, 'page_label': '410'}, page_content='IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nSCRUM Tools\n• There are many tools available to manage\nthe SCRUM process development.\n– Targetprocess\n– Trello'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 410, 'page_label': '411'}, page_content='IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nActivity\n• Form your project group.\n• Choose a Scrum Master for your group.\n• Chose 1-designer, 2-developers and 1 QA\nEngineer.\n• Consider the lecturer as the Product Owner\n• Prepare user stories for your case study (at\nleast 10)\n• Prioritize and arrange them in product\nbacklog.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 411, 'page_label': '412'}, page_content='IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nActivity Contd…\n• Select user stories from the product backlog\ninto three releases.\n• Select a release and prepare the sprint\nbacklog.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 412, 'page_label': '413'}, page_content='IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nReferences\n• "What is Agile Software Development?", Agile Alliance, 2017. [Online]. \nAvailable: https://www.agilealliance.org/agile101/\n• "What is Agile Manifesto? - Definition from WhatIs.com", SearchCIO, \n2017. [Online]. Available: \nhttp://searchcio.techtarget.com/definition/Agile-Manifesto\n• "Manifesto for Agile Software Development",Agilemanifesto.org, \n2017. [Online]. Available: \nhttp://agilemanifesto.org/iso/en/manifesto.html\n• "What is Scrum?", Scrum.org, 2017. [Online]. Available: \nhttps://www.scrum.org/resources/what-is-scrum/\n• Lean Software Development: An Agile Toolkit, Mary and Tom \nPoppendieck, 2003, Addison Wesley'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 413, 'page_label': '414'}, page_content='IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nFinal Exam\nSoftware Process Modelling'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 414, 'page_label': '415'}, page_content='IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nAssessment Criteria\nMid Term Examination 30%  \nLO1-LO4\nAssignment I 10%\nLO3-LO5\nAssignment II 10%\nLO4-LO5\nFinal Examination 50%\nLO1-LO9\nSLIIT 2'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 415, 'page_label': '416'}, page_content='IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nFinal Exam\n• 2 Hour Paper\n• 10 minutes reading time\n– No writing during the 10 minutes\n• Writing booklets and rough paper will be \ngiven\n• If anything important is written, attach the \nrough papers\n• Write all the assumptions you make'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 416, 'page_label': '417'}, page_content='IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nFinal Exam Structure\n• Question 1 –Use Case Diagram\n– Case study based\n– Marking guide –example\n• UseCases - 0.5 *20 =10 marks\n• Actors - 0.5 * 4 = 2 Marks\n• Actor Generalisation - 1 * 3 = 3 Marks\n• Include\n– 7 to 9 = 5 Marks\n– <6 - 0.5 each\n• Extend\n– 1 *5 = 5 Marks\n• Generalisation\n– 0.5 * 8 = 4 Marks\n• Overall - = 1 Mark'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 417, 'page_label': '418'}, page_content='IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nFinal Exam Structure\n• Question 2 – Activity Diagram/ Use Case\nScenario\n– Case study based\n– Marking Scheme –example\n• Swim Lanes = 3 Marks\n• Actions - 0.5 * 16 = 8 Marks\n• Decision - 1 * 4 = 4 Marks\n• Fork - 1 * 2 = 2 Marks\n• Start = 1 Mark\n• End - 0.5*2 = 1 Mark\n• Overall = 1 Mark'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 418, 'page_label': '419'}, page_content='IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nFinal Exam Structure\n• Question 3 –covering all the sections\n–Fill in the blanks + structured + essay\n•SDLC Models\n•Phases of waterfall model\n•Agile and Scrum\n–May be related to tutorials and labs'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf', 'total_pages': 420, 'page': 419, 'page_label': '420'}, page_content='IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing')]

# %%
doc_splitter = RecursiveCharacterTextSplitter(chunk_size=520,chunk_overlap=20)

# %%
doc_chunks=doc_splitter.split_documents(documents)

# %%
len(doc_chunks)
# Out:
# 461

# %%
embedding=GoogleGenerativeAIEmbeddings(model="models/embedding-001")

# %%
vectorindex_gemini=FAISS.from_documents(doc_chunks,embedding)

# %%
vectorindex_gemini

# %%
vectorindex_gemini.save_local('vectorindex_gemini_01')

# %%
vectorindex_load=FAISS.load_local('vectorindex_gemini_01',embedding,allow_dangerous_deserialization=True)

# %%
chain=RetrievalQAWithSourcesChain.from_llm(llm=llm,retriever=vectorindex_load.as_retriever())

# %%
chain
# Out:
# RetrievalQAWithSourcesChain(verbose=False, combine_documents_chain=MapReduceDocumentsChain(verbose=False, llm_chain=LLMChain(verbose=False, prompt=PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template='Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\n{context}\nQuestion: {question}\nRelevant text, if any:'), llm=ChatGoogleGenerativeAI(model='models/gemini-2.0-flash', google_api_key=SecretStr('**********'), client=<google.ai.generativelanguage_v1beta.services.generative_service.client.GenerativeServiceClient object at 0x0000029B0F8EB1D0>, default_metadata=()), output_parser=StrOutputParser(), llm_kwargs={}), reduce_documents_chain=ReduceDocumentsChain(verbose=False, combine_documents_chain=StuffDocumentsChain(verbose=False, llm_chain=LLMChain(verbose=False, prompt=PromptTemplate(input_variables=['question', 'summaries'], input_types={}, partial_variables={}, template='Given the following extracted parts of a long document and a question, create a final answer with references ("SOURCES"). \nIf you don\'t know the answer, just say that you don\'t know. Don\'t try to make up an answer.\nALWAYS return a "SOURCES" part in your answer.\n\nQUESTION: Which state/country\'s law governs the interpretation of the contract?\n=========\nContent: This Agreement is governed by English law and the parties submit to the exclusive jurisdiction of the English courts in  relation to any dispute (contractual or non-contractual) concerning this Agreement save that either party may apply to any court for an  injunction or other relief to protect its Intellectual Property Rights.\nSource: 28-pl\nContent: No Waiver. Failure or delay in exercising any right or remedy under this Agreement shall not constitute a waiver of such (or any other)  right or remedy.\n\n11.7 Severability. The invalidity, illegality or unenforceability of any term (or part of a term) of this Agreement shall not affect the continuation  in force of the remainder of the term (if any) and this Agreement.\n\n11.8 No Agency. Except as expressly stated otherwise, nothing in this Agreement shall create an agency, partnership or joint venture of any  kind between the parties.\n\n11.9 No Third-Party Beneficiaries.\nSource: 30-pl\nContent: (b) if Google believes, in good faith, that the Distributor has violated or caused Google to violate any Anti-Bribery Laws (as  defined in Clause 8.5) or that such a violation is reasonably likely to occur,\nSource: 4-pl\n=========\nFINAL ANSWER: This Agreement is governed by English law.\nSOURCES: 28-pl\n\nQUESTION: What did the president say about Michael Jackson?\n=========\nContent: Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.  \n\nLast year COVID-19 kept us apart. This year we are finally together again. \n\nTonight, we meet as Democrats Republicans and Independents. But most importantly as Americans. \n\nWith a duty to one another to the American people to the Constitution. \n\nAnd with an unwavering resolve that freedom will always triumph over tyranny. \n\nSix days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated. \n\nHe thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined. \n\nHe met the Ukrainian people. \n\nFrom President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world. \n\nGroups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers turned soldiers defending their homeland.\nSource: 0-pl\nContent: And we won’t stop. \n\nWe have lost so much to COVID-19. Time with one another. And worst of all, so much loss of life. \n\nLet ...

# %%
import langchain

# %%
query="what are the Traditional Approaches of Life Cycle Models"

langchain.debug=True

chain({'question':query},return_only_outputs=True)
# Out:
# C:\Users\saifu\AppData\Local\Temp\ipykernel_19524\1132055143.py:5: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   chain({'question':query},return_only_outputs=True)
# [chain/start] [chain:RetrievalQAWithSourcesChain] Entering Chain run with input:
# {
#   "question": "what are the Traditional Approaches of Life Cycle Models"
# }
# [chain/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain] Entering Chain run with input:
# [inputs]
# [chain/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] Entering Chain run with input:
# {
#   "input_list": [
#     {
#       "context": "SLIIT  - Faculty of Computing\nIT 1060\nLife Cycle Model (Process Model)\n• A software life cycle (process) model:\n• is a descriptive and diagrammatic model \nof the life cycle of a software product;\n• identifies all the activities and phases \nnecessary for software development;\n• establishes a precedence ordering among \nthe different activities.\n• Life cycle models encourage systematic \nand disciplined software development.\nSLIIT 11",
#       "question": "what are the Traditional Approaches of Life Cycle Models"
#     },
#     {
#       "context": "SLIIT  - Faculty of Computing\nIT 1060\nLife Cycle Models\n• Traditional Approaches\n1. Waterfall Model\n2. Incremental Model\n3. Prototyping Model\n4. Spiral Model\n5. Unified Process\n• Modern Approaches\n• Agile Methods (XP , Scrum)\n• Secure Software Development",
#       "question": "what are the Traditional Approaches of Life Cycle Models"
#     },
#     {
#       "context": "SLIIT  - Faculty of Computing\nIT 1060\nLife Cycle Models",
#       "question": "what are the Traditional Approaches of Life Cycle Models"
#     },
#     {
#       "context": "SLIIT  - Faculty of Computing\nIT1060\nSoftware Development Life Cycle \nModels \n•A Software Development Life Cycle Model\n•has a series of stages that a software \nproduct undergoes during its life time.\n•is a descriptive and diagrammatic \nrepresentation of the software life cycle.\n•is often referred as software process model.\n•maps the basic development activities to \nphases in different ways",
#       "question": "what are the Traditional Approaches of Life Cycle Models"
#     }
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nSLIIT  - Faculty of Computing\nIT 1060\nLife Cycle Model (Process Model)\n• A software life cycle (process) model:\n• is a descriptive and diagrammatic model \nof the life cycle of a software product;\n• identifies all the activities and phases \nnecessary for software development;\n• establishes a precedence ordering among \nthe different activities.\n• Life cycle models encourage systematic \nand disciplined software development.\nSLIIT 11\nQuestion: what are the Traditional Approaches of Life Cycle Models\nRelevant text, if any:"
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nSLIIT  - Faculty of Computing\nIT 1060\nLife Cycle Models\n• Traditional Approaches\n1. Waterfall Model\n2. Incremental Model\n3. Prototyping Model\n4. Spiral Model\n5. Unified Process\n• Modern Approaches\n• Agile Methods (XP , Scrum)\n• Secure Software Development\nQuestion: what are the Traditional Approaches of Life Cycle Models\nRelevant text, if any:"
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nSLIIT  - Faculty of Computing\nIT 1060\nLife Cycle Models\nQuestion: what are the Traditional Approaches of Life Cycle Models\nRelevant text, if any:"
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nSLIIT  - Faculty of Computing\nIT1060\nSoftware Development Life Cycle \nModels \n•A Software Development Life Cycle Model\n•has a series of stages that a software \nproduct undergoes during its life time.\n•is a descriptive and diagrammatic \nrepresentation of the software life cycle.\n•is often referred as software process model.\n•maps the basic development activities to \nphases in different ways\nQuestion: what are the Traditional Approaches of Life Cycle Models\nRelevant text, if any:"
#   ]
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [4.61s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "The provided text does not contain information about \"Traditional Approaches of Life Cycle Models.\"",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "The provided text does not contain information about \"Traditional Approaches of Life Cycle Models.\"",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-d9ab5305-3c56-4089-97a8-2d454d1266d6-0",
#             "usage_metadata": {
#               "input_tokens": 151,
#               "output_tokens": 17,
#               "total_tokens": 168,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [4.61s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "SLIIT  - Faculty of Computing\nIT 1060\nLife Cycle Models\n• Traditional Approaches\n1. Waterfall Model\n2. Incremental Model\n3. Prototyping Model\n4. Spiral Model\n5. Unified Process",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "SLIIT  - Faculty of Computing\nIT 1060\nLife Cycle Models\n• Traditional Approaches\n1. Waterfall Model\n2. Incremental Model\n3. Prototyping Model\n4. Spiral Model\n5. Unified Process",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-f940751e-0e71-4ef9-9597-ecee62f6ed3d-0",
#             "usage_metadata": {
#               "input_tokens": 116,
#               "output_tokens": 49,
#               "total_tokens": 165,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [4.61s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "SLIIT  - Faculty of Computing\nIT 1060\nLife Cycle Models",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "SLIIT  - Faculty of Computing\nIT 1060\nLife Cycle Models",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-163e9c21-75e7-4ba1-bccb-822cf7b86362-0",
#             "usage_metadata": {
#               "input_tokens": 68,
#               "output_tokens": 19,
#               "total_tokens": 87,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [4.61s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "There is no information about \"Traditional Approaches of Life Cycle Models\" in the provided text.",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "There is no information about \"Traditional Approaches of Life Cycle Models\" in the provided text.",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-ae0b3c9e-2edd-4e2e-a877-76729f82a171-0",
#             "usage_metadata": {
#               "input_tokens": 140,
#               "output_tokens": 19,
#               "total_tokens": 159,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] [4.61s] Exiting Chain run with output:
# {
#   "outputs": [
#     {
#       "text": "The provided text does not contain information about \"Traditional Approaches of Life Cycle Models.\""
#     },
#     {
#       "text": "SLIIT  - Faculty of Computing\nIT 1060\nLife Cycle Models\n• Traditional Approaches\n1. Waterfall Model\n2. Incremental Model\n3. Prototyping Model\n4. Spiral Model\n5. Unified Process"
#     },
#     {
#       "text": "SLIIT  - Faculty of Computing\nIT 1060\nLife Cycle Models"
#     },
#     {
#       "text": "There is no information about \"Traditional Approaches of Life Cycle Models\" in the provided text."
#     }
#   ]
# }
# [chain/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] Entering Chain run with input:
# {
#   "question": "what are the Traditional Approaches of Life Cycle Models",
#   "summaries": "Content: The provided text does not contain information about \"Traditional Approaches of Life Cycle Models.\"\nSource: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf\n\nContent: SLIIT  - Faculty of Computing\nIT 1060\nLife Cycle Models\n• Traditional Approaches\n1. Waterfall Model\n2. Incremental Model\n3. Prototyping Model\n4. Spiral Model\n5. Unified Process\nSource: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf\n\nContent: SLIIT  - Faculty of Computing\nIT 1060\nLife Cycle Models\nSource: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf\n\nContent: There is no information about \"Traditional Approaches of Life Cycle Models\" in the provided text.\nSource: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf"
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Given the following extracted parts of a long document and a question, create a final answer with references (\"SOURCES\"). \nIf you don't know the answer, just say that you don't know. Don't try to make up an answer.\nALWAYS return a \"SOURCES\" part in your answer.\n\nQUESTION: Which state/country's law governs the interpretation of the contract?\n=========\nContent: This Agreement is governed by English law and the parties submit to the exclusive jurisdiction of the English courts in  relation to any dispute (contractual or non-contractual) concerning this Agreement save that either party may apply to any court for an  injunction or other relief to protect its Intellectual Property Rights.\nSource: 28-pl\nContent: No Waiver. Failure or delay in exercising any right or remedy under this Agreement shall not constitute a waiver of such (or any other)  right or remedy.\n\n11.7 Severability. The invalidity, illegality or unenforceability of any term (or part of a term) of this Agreement shall not affect the continuation  in force of the remainder of the term (if any) and this Agreement.\n\n11.8 No Agency. Except as expressly stated otherwise, nothing in this Agreement shall create an agency, partnership or joint venture of any  kind between the parties.\n\n11.9 No Third-Party Beneficiaries.\nSource: 30-pl\nContent: (b) if Google believes, in good faith, that the Distributor has violated or caused Google to violate any Anti-Bribery Laws (as  defined in Clause 8.5) or that such a violation is reasonably likely to occur,\nSource: 4-pl\n=========\nFINAL ANSWER: This Agreement is governed by English law.\nSOURCES: 28-pl\n\nQUESTION: What did the president say about Michael Jackson?\n=========\nContent: Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.  \n\nLast year COVID-19 kept us apart. This year we are finally together again. \n\nTonight, we meet as Democrats Republicans and Independents. But most importantly as Americans. \n\nWith a duty to one another to the American people to the Constitution. \n\nAnd with an unwavering resolve that freedom will always triumph over tyranny. \n\nSix days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated. \n\nHe thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined. \n\nHe met the Ukrainian people. \n\nFrom President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world. \n\nGroups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers turned soldiers defending their homeland.\nSource: 0-pl\nContent: And we won’t stop. \n\nWe have lost so much to COVID-19. Time with one another. And worst of all, so much loss of life. \n\nLet’s use this moment to reset. Let’s stop looking at COVID-19 as a partisan dividing line and see it for what it is: A God-awful disease.  \n\nLet’s stop seeing each other as enemies, and start seeing each other for who we really are: Fellow Americans.  \n\nWe can’t change how divided we’ve been. But we can change how we move forward—on COVID-19 and other issues we must face together. \n\nI recently visited the New York City Police Department days after the funerals of Officer Wilbert Mora and his partner, Officer Jason Rivera. \n\nThey were responding to a 9-1-1 call when a man shot and killed them with a stolen gun. \n\nOfficer Mora was 27 years old. \n\nOfficer Rivera was 22. \n\nBoth Dominican Americans who’d grown up on the same streets they later chose to patrol as police officers. \n\nI spoke with their families and told them that we are forever in debt for their sacrifice, and we will carry on their mission to restore the trust and safety every community deserves.\nSource: 24-pl\nContent: And ...
#   ]
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [1.84s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "The traditional approaches of Life Cycle Models are:\n1. Waterfall Model\n2. Incremental Model\n3. Prototyping Model\n4. Spiral Model\n5. Unified Process\nSOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "The traditional approaches of Life Cycle Models are:\n1. Waterfall Model\n2. Incremental Model\n3. Prototyping Model\n4. Spiral Model\n5. Unified Process\nSOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-a3145959-abfc-400b-b9bd-9e13bb69b905-0",
#             "usage_metadata": {
#               "input_tokens": 1643,
#               "output_tokens": 60,
#               "total_tokens": 1703,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] [1.84s] Exiting Chain run with output:
# {
#   "text": "The traditional approaches of Life Cycle Models are:\n1. Waterfall Model\n2. Incremental Model\n3. Prototyping Model\n4. Spiral Model\n5. Unified Process\nSOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain] [7.12s] Exiting Chain run with output:
# {
#   "output_text": "The traditional approaches of Life Cycle Models are:\n1. Waterfall Model\n2. Incremental Model\n3. Prototyping Model\n4. Spiral Model\n5. Unified Process\nSOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain] [9.32s] Exiting Chain run with output:
# {
#   "answer": "The traditional approaches of Life Cycle Models are:\n1. Waterfall Model\n2. Incremental Model\n3. Prototyping Model\n4. Spiral Model\n5. Unified Process\n",
#   "sources": "C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf"
# }
# {'answer': 'The traditional approaches of Life Cycle Models are:\n1. Waterfall Model\n2. Incremental Model\n3. Prototyping Model\n4. Spiral Model\n5. Unified Process\n',
#  'sources': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf'}

# %%
query="what is a fork?"

langchain.debug=True

chain({'question':query},return_only_outputs=True)
# Out:
# [chain/start] [chain:RetrievalQAWithSourcesChain] Entering Chain run with input:
# {
#   "question": "what is a fork?"
# }
# [chain/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain] Entering Chain run with input:
# [inputs]
# [chain/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] Entering Chain run with input:
# {
#   "input_list": [
#     {
#       "context": "IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nFork\n• A fork is when a single flow of control splits into\ntwo or more parallel (concurrent) flows of\ncontrol.\n• Represents a split in the flow of control.",
#       "question": "what is a fork?"
#     },
#     {
#       "context": "IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nForks & Joins\n• Forks and joins are used to showing activities that\ncan occur at the same time (in parallel).\n– this does not mean that the activities must occur\nconcurrently in the finished software system.\n– it means that the order of execution of the\nactivities can be whatever is convenient for the\nimplementation.",
#       "question": "what is a fork?"
#     },
#     {
#       "context": "IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nFork\n• Unlike a branch point, the control flows down all\nforked paths.\n• With a branch point, the control flows down only one\npath.",
#       "question": "what is a fork?"
#     },
#     {
#       "context": "IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nCommon Mistakes\n• Incorrect use of forks,\nbranch points, merge\npoints and joins.\n• The fork means that the\nflow of control goes down\nboth paths.\n• The merge point indicates\na merging of divergent\npaths, not flows.",
#       "question": "what is a fork?"
#     }
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nIT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nFork\n• A fork is when a single flow of control splits into\ntwo or more parallel (concurrent) flows of\ncontrol.\n• Represents a split in the flow of control.\nQuestion: what is a fork?\nRelevant text, if any:"
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nIT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nForks & Joins\n• Forks and joins are used to showing activities that\ncan occur at the same time (in parallel).\n– this does not mean that the activities must occur\nconcurrently in the finished software system.\n– it means that the order of execution of the\nactivities can be whatever is convenient for the\nimplementation.\nQuestion: what is a fork?\nRelevant text, if any:"
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nIT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nFork\n• Unlike a branch point, the control flows down all\nforked paths.\n• With a branch point, the control flows down only one\npath.\nQuestion: what is a fork?\nRelevant text, if any:"
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nIT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nCommon Mistakes\n• Incorrect use of forks,\nbranch points, merge\npoints and joins.\n• The fork means that the\nflow of control goes down\nboth paths.\n• The merge point indicates\na merging of divergent\npaths, not flows.\nQuestion: what is a fork?\nRelevant text, if any:"
#   ]
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [3.15s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "• A fork is when a single flow of control splits into\ntwo or more parallel (concurrent) flows of\ncontrol.\n• Represents a split in the flow of control.",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "• A fork is when a single flow of control splits into\ntwo or more parallel (concurrent) flows of\ncontrol.\n• Represents a split in the flow of control.",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-c12c0b99-8b7d-4502-a3d4-63c401b34b46-0",
#             "usage_metadata": {
#               "input_tokens": 102,
#               "output_tokens": 37,
#               "total_tokens": 139,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [3.15s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "Forks & Joins\n• Forks and joins are used to showing activities that\ncan occur at the same time (in parallel).",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "Forks & Joins\n• Forks and joins are used to showing activities that\ncan occur at the same time (in parallel).",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-72105089-667f-4fa3-89be-6bfa5a5b0775-0",
#             "usage_metadata": {
#               "input_tokens": 133,
#               "output_tokens": 27,
#               "total_tokens": 160,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [3.15s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "• Unlike a branch point, the control flows down all\nforked paths.",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "• Unlike a branch point, the control flows down all\nforked paths.",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-432021ae-4312-4f18-b851-59c2676aeeab-0",
#             "usage_metadata": {
#               "input_tokens": 98,
#               "output_tokens": 17,
#               "total_tokens": 115,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [3.15s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "• The fork means that the\nflow of control goes down\nboth paths.",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "• The fork means that the\nflow of control goes down\nboth paths.",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-d612764e-1915-470e-b529-6360e9bb57c6-0",
#             "usage_metadata": {
#               "input_tokens": 117,
#               "output_tokens": 17,
#               "total_tokens": 134,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] [3.15s] Exiting Chain run with output:
# {
#   "outputs": [
#     {
#       "text": "• A fork is when a single flow of control splits into\ntwo or more parallel (concurrent) flows of\ncontrol.\n• Represents a split in the flow of control."
#     },
#     {
#       "text": "Forks & Joins\n• Forks and joins are used to showing activities that\ncan occur at the same time (in parallel)."
#     },
#     {
#       "text": "• Unlike a branch point, the control flows down all\nforked paths."
#     },
#     {
#       "text": "• The fork means that the\nflow of control goes down\nboth paths."
#     }
#   ]
# }
# [chain/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] Entering Chain run with input:
# {
#   "question": "what is a fork?",
#   "summaries": "Content: • A fork is when a single flow of control splits into\ntwo or more parallel (concurrent) flows of\ncontrol.\n• Represents a split in the flow of control.\nSource: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf\n\nContent: Forks & Joins\n• Forks and joins are used to showing activities that\ncan occur at the same time (in parallel).\nSource: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf\n\nContent: • Unlike a branch point, the control flows down all\nforked paths.\nSource: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf\n\nContent: • The fork means that the\nflow of control goes down\nboth paths.\nSource: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf"
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Given the following extracted parts of a long document and a question, create a final answer with references (\"SOURCES\"). \nIf you don't know the answer, just say that you don't know. Don't try to make up an answer.\nALWAYS return a \"SOURCES\" part in your answer.\n\nQUESTION: Which state/country's law governs the interpretation of the contract?\n=========\nContent: This Agreement is governed by English law and the parties submit to the exclusive jurisdiction of the English courts in  relation to any dispute (contractual or non-contractual) concerning this Agreement save that either party may apply to any court for an  injunction or other relief to protect its Intellectual Property Rights.\nSource: 28-pl\nContent: No Waiver. Failure or delay in exercising any right or remedy under this Agreement shall not constitute a waiver of such (or any other)  right or remedy.\n\n11.7 Severability. The invalidity, illegality or unenforceability of any term (or part of a term) of this Agreement shall not affect the continuation  in force of the remainder of the term (if any) and this Agreement.\n\n11.8 No Agency. Except as expressly stated otherwise, nothing in this Agreement shall create an agency, partnership or joint venture of any  kind between the parties.\n\n11.9 No Third-Party Beneficiaries.\nSource: 30-pl\nContent: (b) if Google believes, in good faith, that the Distributor has violated or caused Google to violate any Anti-Bribery Laws (as  defined in Clause 8.5) or that such a violation is reasonably likely to occur,\nSource: 4-pl\n=========\nFINAL ANSWER: This Agreement is governed by English law.\nSOURCES: 28-pl\n\nQUESTION: What did the president say about Michael Jackson?\n=========\nContent: Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.  \n\nLast year COVID-19 kept us apart. This year we are finally together again. \n\nTonight, we meet as Democrats Republicans and Independents. But most importantly as Americans. \n\nWith a duty to one another to the American people to the Constitution. \n\nAnd with an unwavering resolve that freedom will always triumph over tyranny. \n\nSix days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated. \n\nHe thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined. \n\nHe met the Ukrainian people. \n\nFrom President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world. \n\nGroups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers turned soldiers defending their homeland.\nSource: 0-pl\nContent: And we won’t stop. \n\nWe have lost so much to COVID-19. Time with one another. And worst of all, so much loss of life. \n\nLet’s use this moment to reset. Let’s stop looking at COVID-19 as a partisan dividing line and see it for what it is: A God-awful disease.  \n\nLet’s stop seeing each other as enemies, and start seeing each other for who we really are: Fellow Americans.  \n\nWe can’t change how divided we’ve been. But we can change how we move forward—on COVID-19 and other issues we must face together. \n\nI recently visited the New York City Police Department days after the funerals of Officer Wilbert Mora and his partner, Officer Jason Rivera. \n\nThey were responding to a 9-1-1 call when a man shot and killed them with a stolen gun. \n\nOfficer Mora was 27 years old. \n\nOfficer Rivera was 22. \n\nBoth Dominican Americans who’d grown up on the same streets they later chose to patrol as police officers. \n\nI spoke with their families and told them that we are forever in debt for their sacrifice, and we will carry on their mission to restore the trust and safety every community deserves.\nSource: 24-pl\nContent: And ...
#   ]
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [1.27s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "A fork is when a single flow of control splits into two or more parallel (concurrent) flows of control, representing a split in the flow of control. Unlike a branch point, the control flows down all forked paths.\nSOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "A fork is when a single flow of control splits into two or more parallel (concurrent) flows of control, representing a split in the flow of control. Unlike a branch point, the control flows down all forked paths.\nSOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-a328a748-bd53-4b48-aafb-8b32a7b012c1-0",
#             "usage_metadata": {
#               "input_tokens": 1630,
#               "output_tokens": 69,
#               "total_tokens": 1699,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] [1.27s] Exiting Chain run with output:
# {
#   "text": "A fork is when a single flow of control splits into two or more parallel (concurrent) flows of control, representing a split in the flow of control. Unlike a branch point, the control flows down all forked paths.\nSOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain] [5.10s] Exiting Chain run with output:
# {
#   "output_text": "A fork is when a single flow of control splits into two or more parallel (concurrent) flows of control, representing a split in the flow of control. Unlike a branch point, the control flows down all forked paths.\nSOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain] [5.61s] Exiting Chain run with output:
# {
#   "answer": "A fork is when a single flow of control splits into two or more parallel (concurrent) flows of control, representing a split in the flow of control. Unlike a branch point, the control flows down all forked paths.\n",
#   "sources": "C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf"
# }
# {'answer': 'A fork is when a single flow of control splits into two or more parallel (concurrent) flows of control, representing a split in the flow of control. Unlike a branch point, the control flows down all forked paths.\n',
#  'sources': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf'}

# %%
query="what is Partitioning"

langchain.debug=True

chain({'question':query},return_only_outputs=True)
# Out:
# [chain/start] [chain:RetrievalQAWithSourcesChain] Entering Chain run with input:
# {
#   "question": "what is Partitioning"
# }
# [chain/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain] Entering Chain run with input:
# [inputs]
# [chain/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] Entering Chain run with input:
# {
#   "input_list": [
#     {
#       "context": "IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nPartitioning\n• An activity partition is an activity group for\nactions that have some common characteristic.\n• Partitions often correspond to organizational\nunits or business actors in a business model.",
#       "question": "what is Partitioning"
#     },
#     {
#       "context": "IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nEquivalence partitions\n• In equivalence-partitioning technique we need \nto test only one condition from each partition. \n– This is because we are assuming that all the \nconditions in one partition will be treated in the \nsame way by the software. \n• Equivalence partitioning is an effective \napproach to testing because it helps to reduce \nthe number of tests.\nRef: Software Engineering, I. Sommerville,  10th Edition",
#       "question": "what is Partitioning"
#     },
#     {
#       "context": "IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nEquivalence partitioning \nExample \n• Example of a function which takes a parameter \n“month”.\n• The valid range for the month is 1 to 12, \nrepresenting January to December. This valid \nrange is called a partition.\n• In this example there are two further partitions \nof invalid ranges.\nx < 1 1 ≤ x ≤ 12 12 < x",
#       "question": "what is Partitioning"
#     },
#     {
#       "context": "IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nEquivalence partitioning \nExample \n• Test cases are chosen so that each partition \nwould be tested.\nx < 1 1 ≤ x ≤ 12 12 < x\n-2 5 17",
#       "question": "what is Partitioning"
#     }
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nIT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nPartitioning\n• An activity partition is an activity group for\nactions that have some common characteristic.\n• Partitions often correspond to organizational\nunits or business actors in a business model.\nQuestion: what is Partitioning\nRelevant text, if any:"
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nIT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nEquivalence partitions\n• In equivalence-partitioning technique we need \nto test only one condition from each partition. \n– This is because we are assuming that all the \nconditions in one partition will be treated in the \nsame way by the software. \n• Equivalence partitioning is an effective \napproach to testing because it helps to reduce \nthe number of tests.\nRef: Software Engineering, I. Sommerville,  10th Edition\nQuestion: what is Partitioning\nRelevant text, if any:"
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nIT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nEquivalence partitioning \nExample \n• Example of a function which takes a parameter \n“month”.\n• The valid range for the month is 1 to 12, \nrepresenting January to December. This valid \nrange is called a partition.\n• In this example there are two further partitions \nof invalid ranges.\nx < 1 1 ≤ x ≤ 12 12 < x\nQuestion: what is Partitioning\nRelevant text, if any:"
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nIT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nEquivalence partitioning \nExample \n• Test cases are chosen so that each partition \nwould be tested.\nx < 1 1 ≤ x ≤ 12 12 < x\n-2 5 17\nQuestion: what is Partitioning\nRelevant text, if any:"
#   ]
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [4.13s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "• An activity partition is an activity group for\nactions that have some common characteristic.\n• Partitions often correspond to organizational\nunits or business actors in a business model.",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "• An activity partition is an activity group for\nactions that have some common characteristic.\n• Partitions often correspond to organizational\nunits or business actors in a business model.",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-8896c9fa-2fa5-434f-a3bc-ae3db989ac89-0",
#             "usage_metadata": {
#               "input_tokens": 101,
#               "output_tokens": 36,
#               "total_tokens": 137,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [4.13s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "Equivalence partitions\n• In equivalence-partitioning technique we need \nto test only one condition from each partition. \n– This is because we are assuming that all the \nconditions in one partition will be treated in the \nsame way by the software. \n• Equivalence partitioning is an effective \napproach to testing because it helps to reduce \nthe number of tests.",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "Equivalence partitions\n• In equivalence-partitioning technique we need \nto test only one condition from each partition. \n– This is because we are assuming that all the \nconditions in one partition will be treated in the \nsame way by the software. \n• Equivalence partitioning is an effective \napproach to testing because it helps to reduce \nthe number of tests.",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-3f775735-1df8-4fd1-985b-ee4673bd4b8f-0",
#             "usage_metadata": {
#               "input_tokens": 161,
#               "output_tokens": 82,
#               "total_tokens": 243,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [4.13s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "Equivalence partitioning \nExample \n• Example of a function which takes a parameter \n“month”.\n• The valid range for the month is 1 to 12, \nrepresenting January to December. This valid \nrange is called a partition.\n• In this example there are two further partitions \nof invalid ranges.\nx < 1 1 ≤ x ≤ 12 12 < x",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "Equivalence partitioning \nExample \n• Example of a function which takes a parameter \n“month”.\n• The valid range for the month is 1 to 12, \nrepresenting January to December. This valid \nrange is called a partition.\n• In this example there are two further partitions \nof invalid ranges.\nx < 1 1 ≤ x ≤ 12 12 < x",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-c3294c7b-c2cb-450d-9358-f7a232c0c5e4-0",
#             "usage_metadata": {
#               "input_tokens": 152,
#               "output_tokens": 90,
#               "total_tokens": 242,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [4.13s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "Equivalence partitioning \nExample \n• Test cases are chosen so that each partition \nwould be tested.",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "Equivalence partitioning \nExample \n• Test cases are chosen so that each partition \nwould be tested.",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-7e083edf-061a-4ac4-bd61-9c019573f937-0",
#             "usage_metadata": {
#               "input_tokens": 112,
#               "output_tokens": 24,
#               "total_tokens": 136,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] [4.13s] Exiting Chain run with output:
# {
#   "outputs": [
#     {
#       "text": "• An activity partition is an activity group for\nactions that have some common characteristic.\n• Partitions often correspond to organizational\nunits or business actors in a business model."
#     },
#     {
#       "text": "Equivalence partitions\n• In equivalence-partitioning technique we need \nto test only one condition from each partition. \n– This is because we are assuming that all the \nconditions in one partition will be treated in the \nsame way by the software. \n• Equivalence partitioning is an effective \napproach to testing because it helps to reduce \nthe number of tests."
#     },
#     {
#       "text": "Equivalence partitioning \nExample \n• Example of a function which takes a parameter \n“month”.\n• The valid range for the month is 1 to 12, \nrepresenting January to December. This valid \nrange is called a partition.\n• In this example there are two further partitions \nof invalid ranges.\nx < 1 1 ≤ x ≤ 12 12 < x"
#     },
#     {
#       "text": "Equivalence partitioning \nExample \n• Test cases are chosen so that each partition \nwould be tested."
#     }
#   ]
# }
# [chain/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] Entering Chain run with input:
# {
#   "question": "what is Partitioning",
#   "summaries": "Content: • An activity partition is an activity group for\nactions that have some common characteristic.\n• Partitions often correspond to organizational\nunits or business actors in a business model.\nSource: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf\n\nContent: Equivalence partitions\n• In equivalence-partitioning technique we need \nto test only one condition from each partition. \n– This is because we are assuming that all the \nconditions in one partition will be treated in the \nsame way by the software. \n• Equivalence partitioning is an effective \napproach to testing because it helps to reduce \nthe number of tests.\nSource: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf\n\nContent: Equivalence partitioning \nExample \n• Example of a function which takes a parameter \n“month”.\n• The valid range for the month is 1 to 12, \nrepresenting January to December. This valid \nrange is called a partition.\n• In this example there are two further partitions \nof invalid ranges.\nx < 1 1 ≤ x ≤ 12 12 < x\nSource: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf\n\nContent: Equivalence partitioning \nExample \n• Test cases are chosen so that each partition \nwould be tested.\nSource: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf"
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Given the following extracted parts of a long document and a question, create a final answer with references (\"SOURCES\"). \nIf you don't know the answer, just say that you don't know. Don't try to make up an answer.\nALWAYS return a \"SOURCES\" part in your answer.\n\nQUESTION: Which state/country's law governs the interpretation of the contract?\n=========\nContent: This Agreement is governed by English law and the parties submit to the exclusive jurisdiction of the English courts in  relation to any dispute (contractual or non-contractual) concerning this Agreement save that either party may apply to any court for an  injunction or other relief to protect its Intellectual Property Rights.\nSource: 28-pl\nContent: No Waiver. Failure or delay in exercising any right or remedy under this Agreement shall not constitute a waiver of such (or any other)  right or remedy.\n\n11.7 Severability. The invalidity, illegality or unenforceability of any term (or part of a term) of this Agreement shall not affect the continuation  in force of the remainder of the term (if any) and this Agreement.\n\n11.8 No Agency. Except as expressly stated otherwise, nothing in this Agreement shall create an agency, partnership or joint venture of any  kind between the parties.\n\n11.9 No Third-Party Beneficiaries.\nSource: 30-pl\nContent: (b) if Google believes, in good faith, that the Distributor has violated or caused Google to violate any Anti-Bribery Laws (as  defined in Clause 8.5) or that such a violation is reasonably likely to occur,\nSource: 4-pl\n=========\nFINAL ANSWER: This Agreement is governed by English law.\nSOURCES: 28-pl\n\nQUESTION: What did the president say about Michael Jackson?\n=========\nContent: Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.  \n\nLast year COVID-19 kept us apart. This year we are finally together again. \n\nTonight, we meet as Democrats Republicans and Independents. But most importantly as Americans. \n\nWith a duty to one another to the American people to the Constitution. \n\nAnd with an unwavering resolve that freedom will always triumph over tyranny. \n\nSix days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated. \n\nHe thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined. \n\nHe met the Ukrainian people. \n\nFrom President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world. \n\nGroups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers turned soldiers defending their homeland.\nSource: 0-pl\nContent: And we won’t stop. \n\nWe have lost so much to COVID-19. Time with one another. And worst of all, so much loss of life. \n\nLet’s use this moment to reset. Let’s stop looking at COVID-19 as a partisan dividing line and see it for what it is: A God-awful disease.  \n\nLet’s stop seeing each other as enemies, and start seeing each other for who we really are: Fellow Americans.  \n\nWe can’t change how divided we’ve been. But we can change how we move forward—on COVID-19 and other issues we must face together. \n\nI recently visited the New York City Police Department days after the funerals of Officer Wilbert Mora and his partner, Officer Jason Rivera. \n\nThey were responding to a 9-1-1 call when a man shot and killed them with a stolen gun. \n\nOfficer Mora was 27 years old. \n\nOfficer Rivera was 22. \n\nBoth Dominican Americans who’d grown up on the same streets they later chose to patrol as police officers. \n\nI spoke with their families and told them that we are forever in debt for their sacrifice, and we will carry on their mission to restore the trust and safety every community deserves.\nSource: 24-pl\nContent: And ...
#   ]
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [2.36s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "Partitioning can refer to:\n\n*   An activity group for actions that have some common characteristic, often corresponding to organizational units or business actors in a business model. (SOURCE: C:/Users/saifu/Desktop/rag\\_project1/docs\\\\SPM - all.pdf)\n*   Equivalence partitioning, a testing technique where you test only one condition from each partition, assuming all conditions in one partition will be treated the same way by the software. This helps reduce the number of tests. An example is a function that takes a month as a parameter, where the valid range (1 to 12) is a partition, and there are also invalid ranges (x < 1 and 12 < x) that form other partitions. Test cases are chosen to test each partition. (SOURCE: C:/Users/saifu/Desktop/rag\\_project1/docs\\\\SPM - all.pdf)",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "Partitioning can refer to:\n\n*   An activity group for actions that have some common characteristic, often corresponding to organizational units or business actors in a business model. (SOURCE: C:/Users/saifu/Desktop/rag\\_project1/docs\\\\SPM - all.pdf)\n*   Equivalence partitioning, a testing technique where you test only one condition from each partition, assuming all conditions in one partition will be treated the same way by the software. This helps reduce the number of tests. An example is a function that takes a month as a parameter, where the valid range (1 to 12) is a partition, and there are also invalid ranges (x < 1 and 12 < x) that form other partitions. Test cases are chosen to test each partition. (SOURCE: C:/Users/saifu/Desktop/rag\\_project1/docs\\\\SPM - all.pdf)",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-882f7e32-1980-43ae-8ee2-2ff9d471fa96-0",
#             "usage_metadata": {
#               "input_tokens": 1764,
#               "output_tokens": 187,
#               "total_tokens": 1951,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] [2.36s] Exiting Chain run with output:
# {
#   "text": "Partitioning can refer to:\n\n*   An activity group for actions that have some common characteristic, often corresponding to organizational units or business actors in a business model. (SOURCE: C:/Users/saifu/Desktop/rag\\_project1/docs\\\\SPM - all.pdf)\n*   Equivalence partitioning, a testing technique where you test only one condition from each partition, assuming all conditions in one partition will be treated the same way by the software. This helps reduce the number of tests. An example is a function that takes a month as a parameter, where the valid range (1 to 12) is a partition, and there are also invalid ranges (x < 1 and 12 < x) that form other partitions. Test cases are chosen to test each partition. (SOURCE: C:/Users/saifu/Desktop/rag\\_project1/docs\\\\SPM - all.pdf)"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain] [7.09s] Exiting Chain run with output:
# {
#   "output_text": "Partitioning can refer to:\n\n*   An activity group for actions that have some common characteristic, often corresponding to organizational units or business actors in a business model. (SOURCE: C:/Users/saifu/Desktop/rag\\_project1/docs\\\\SPM - all.pdf)\n*   Equivalence partitioning, a testing technique where you test only one condition from each partition, assuming all conditions in one partition will be treated the same way by the software. This helps reduce the number of tests. An example is a function that takes a month as a parameter, where the valid range (1 to 12) is a partition, and there are also invalid ranges (x < 1 and 12 < x) that form other partitions. Test cases are chosen to test each partition. (SOURCE: C:/Users/saifu/Desktop/rag\\_project1/docs\\\\SPM - all.pdf)"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain] [7.59s] Exiting Chain run with output:
# {
#   "answer": "Partitioning can refer to:\n\n*   An activity group for actions that have some common characteristic, often corresponding to organizational units or business actors in a business model. (",
#   "sources": "C:/Users/saifu/Desktop/rag\\_project1/docs\\\\SPM - all.pdf)"
# }
# {'answer': 'Partitioning can refer to:\n\n*   An activity group for actions that have some common characteristic, often corresponding to organizational units or business actors in a business model. (',
#  'sources': 'C:/Users/saifu/Desktop/rag\\_project1/docs\\\\SPM - all.pdf)'}

# %%
import requests
import pytesseract
from PIL import Image
from io import BytesIO

# %%
# def extract_text_from_image(image_path):
#     respose=requests.get(image_path)
#     img=Image.open(BytesIO(respose.content))
#     extracted_text=pytesseract.image_to_string(img)
#     return extracted_text.strip()

# %%
#the above function only al;low image url-- so need image path also

# %%
# response.content: Gets the binary content of the image.
# BytesIO(response.content): Converts the binary data into a file-like object.
# Image.open(...): Opens the image using PIL (Python Imaging Library).
# extracted_text = pytesseract.image_to_string(img)
# .strip(): Removes leading and trailing whitespaces from the extracted text.

# %%
pytesseract.pytesseract.tesseract_cmd = r"C:\\Program Files\\Tesseract-OCR\\tesseract.exe"

# %%
#new function with both url,path3

def extract_text_from_image(image_source):
    if image_source.startswith('http'):
        response=requests.get(image_source)
        img= Image.open(BytesIO(response.content))
    elif os.path.exists(image_source):
        img=Image.open(image_source)
    else:
        raise ValueError("Invelid image source!")
    
    extracted_text=pytesseract.image_to_string(img)
    return extracted_text.strip()

# %%
image_path="C:/Users/saifu/OneDrive/Pictures/Screenshots 1/Screenshot 2025-02-17 103629.png"
image_url="https://storage.googleapis.com/ticket_book_sb_saif/Screenshot%202025-02-17%20103629.png"

# %%
extracted_text=extract_text_from_image(image_path)

# %%
query=extracted_text

langchain.debug=True

chain({'question':query},return_only_outputs=True)
# Out:
# [chain/start] [chain:RetrievalQAWithSourcesChain] Entering Chain run with input:
# {
#   "question": "Give me the explanation to\n\npartitioning with example."
# }
# [chain/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain] Entering Chain run with input:
# [inputs]
# [chain/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] Entering Chain run with input:
# {
#   "input_list": [
#     {
#       "context": "IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nEquivalence partitioning \nExample \n• Example of a function which takes a parameter \n“month”.\n• The valid range for the month is 1 to 12, \nrepresenting January to December. This valid \nrange is called a partition.\n• In this example there are two further partitions \nof invalid ranges.\nx < 1 1 ≤ x ≤ 12 12 < x",
#       "question": "Give me the explanation to\n\npartitioning with example."
#     },
#     {
#       "context": "IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nEquivalence partitioning \nExample \n• Test cases are chosen so that each partition \nwould be tested.\nx < 1 1 ≤ x ≤ 12 12 < x\n-2 5 17",
#       "question": "Give me the explanation to\n\npartitioning with example."
#     },
#     {
#       "context": "IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nEquivalence partitions\n• In equivalence-partitioning technique we need \nto test only one condition from each partition. \n– This is because we are assuming that all the \nconditions in one partition will be treated in the \nsame way by the software. \n• Equivalence partitioning is an effective \napproach to testing because it helps to reduce \nthe number of tests.\nRef: Software Engineering, I. Sommerville,  10th Edition",
#       "question": "Give me the explanation to\n\npartitioning with example."
#     },
#     {
#       "context": "IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nPartitioning\n• An activity partition is an activity group for\nactions that have some common characteristic.\n• Partitions often correspond to organizational\nunits or business actors in a business model.",
#       "question": "Give me the explanation to\n\npartitioning with example."
#     }
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nIT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nEquivalence partitioning \nExample \n• Example of a function which takes a parameter \n“month”.\n• The valid range for the month is 1 to 12, \nrepresenting January to December. This valid \nrange is called a partition.\n• In this example there are two further partitions \nof invalid ranges.\nx < 1 1 ≤ x ≤ 12 12 < x\nQuestion: Give me the explanation to\n\npartitioning with example.\nRelevant text, if any:"
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nIT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nEquivalence partitioning \nExample \n• Test cases are chosen so that each partition \nwould be tested.\nx < 1 1 ≤ x ≤ 12 12 < x\n-2 5 17\nQuestion: Give me the explanation to\n\npartitioning with example.\nRelevant text, if any:"
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nIT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nEquivalence partitions\n• In equivalence-partitioning technique we need \nto test only one condition from each partition. \n– This is because we are assuming that all the \nconditions in one partition will be treated in the \nsame way by the software. \n• Equivalence partitioning is an effective \napproach to testing because it helps to reduce \nthe number of tests.\nRef: Software Engineering, I. Sommerville,  10th Edition\nQuestion: Give me the explanation to\n\npartitioning with example.\nRelevant text, if any:"
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nIT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nPartitioning\n• An activity partition is an activity group for\nactions that have some common characteristic.\n• Partitions often correspond to organizational\nunits or business actors in a business model.\nQuestion: Give me the explanation to\n\npartitioning with example.\nRelevant text, if any:"
#   ]
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [3.76s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "Equivalence partitioning \nExample \n• Example of a function which takes a parameter \n“month”.\n• The valid range for the month is 1 to 12, \nrepresenting January to December. This valid \nrange is called a partition.\n• In this example there are two further partitions \nof invalid ranges.\nx < 1 1 ≤ x ≤ 12 12 < x",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "Equivalence partitioning \nExample \n• Example of a function which takes a parameter \n“month”.\n• The valid range for the month is 1 to 12, \nrepresenting January to December. This valid \nrange is called a partition.\n• In this example there are two further partitions \nof invalid ranges.\nx < 1 1 ≤ x ≤ 12 12 < x",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-299cd057-7424-4496-9199-7797810696e5-0",
#             "usage_metadata": {
#               "input_tokens": 159,
#               "output_tokens": 90,
#               "total_tokens": 249,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [3.76s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "Equivalence partitioning \nExample \n• Test cases are chosen so that each partition \nwould be tested.\nx < 1 1 ≤ x ≤ 12 12 < x\n-2 5 17",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "Equivalence partitioning \nExample \n• Test cases are chosen so that each partition \nwould be tested.\nx < 1 1 ≤ x ≤ 12 12 < x\n-2 5 17",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-cf111735-c8b2-46a0-b582-2b665fc4eb0d-0",
#             "usage_metadata": {
#               "input_tokens": 119,
#               "output_tokens": 50,
#               "total_tokens": 169,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [3.76s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "Equivalence partitions\n• In equivalence-partitioning technique we need \nto test only one condition from each partition. \n– This is because we are assuming that all the \nconditions in one partition will be treated in the \nsame way by the software. \n• Equivalence partitioning is an effective \napproach to testing because it helps to reduce \nthe number of tests.",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "Equivalence partitions\n• In equivalence-partitioning technique we need \nto test only one condition from each partition. \n– This is because we are assuming that all the \nconditions in one partition will be treated in the \nsame way by the software. \n• Equivalence partitioning is an effective \napproach to testing because it helps to reduce \nthe number of tests.",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-3b0eb64f-94bf-493a-ae64-e38247e45d97-0",
#             "usage_metadata": {
#               "input_tokens": 168,
#               "output_tokens": 82,
#               "total_tokens": 250,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [3.76s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "• An activity partition is an activity group for\nactions that have some common characteristic.\n• Partitions often correspond to organizational\nunits or business actors in a business model.",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "• An activity partition is an activity group for\nactions that have some common characteristic.\n• Partitions often correspond to organizational\nunits or business actors in a business model.",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-6c916636-5949-485e-89d9-96c26db23489-0",
#             "usage_metadata": {
#               "input_tokens": 108,
#               "output_tokens": 36,
#               "total_tokens": 144,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] [3.76s] Exiting Chain run with output:
# {
#   "outputs": [
#     {
#       "text": "Equivalence partitioning \nExample \n• Example of a function which takes a parameter \n“month”.\n• The valid range for the month is 1 to 12, \nrepresenting January to December. This valid \nrange is called a partition.\n• In this example there are two further partitions \nof invalid ranges.\nx < 1 1 ≤ x ≤ 12 12 < x"
#     },
#     {
#       "text": "Equivalence partitioning \nExample \n• Test cases are chosen so that each partition \nwould be tested.\nx < 1 1 ≤ x ≤ 12 12 < x\n-2 5 17"
#     },
#     {
#       "text": "Equivalence partitions\n• In equivalence-partitioning technique we need \nto test only one condition from each partition. \n– This is because we are assuming that all the \nconditions in one partition will be treated in the \nsame way by the software. \n• Equivalence partitioning is an effective \napproach to testing because it helps to reduce \nthe number of tests."
#     },
#     {
#       "text": "• An activity partition is an activity group for\nactions that have some common characteristic.\n• Partitions often correspond to organizational\nunits or business actors in a business model."
#     }
#   ]
# }
# [chain/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] Entering Chain run with input:
# {
#   "question": "Give me the explanation to\n\npartitioning with example.",
#   "summaries": "Content: Equivalence partitioning \nExample \n• Example of a function which takes a parameter \n“month”.\n• The valid range for the month is 1 to 12, \nrepresenting January to December. This valid \nrange is called a partition.\n• In this example there are two further partitions \nof invalid ranges.\nx < 1 1 ≤ x ≤ 12 12 < x\nSource: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf\n\nContent: Equivalence partitioning \nExample \n• Test cases are chosen so that each partition \nwould be tested.\nx < 1 1 ≤ x ≤ 12 12 < x\n-2 5 17\nSource: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf\n\nContent: Equivalence partitions\n• In equivalence-partitioning technique we need \nto test only one condition from each partition. \n– This is because we are assuming that all the \nconditions in one partition will be treated in the \nsame way by the software. \n• Equivalence partitioning is an effective \napproach to testing because it helps to reduce \nthe number of tests.\nSource: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf\n\nContent: • An activity partition is an activity group for\nactions that have some common characteristic.\n• Partitions often correspond to organizational\nunits or business actors in a business model.\nSource: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf"
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Given the following extracted parts of a long document and a question, create a final answer with references (\"SOURCES\"). \nIf you don't know the answer, just say that you don't know. Don't try to make up an answer.\nALWAYS return a \"SOURCES\" part in your answer.\n\nQUESTION: Which state/country's law governs the interpretation of the contract?\n=========\nContent: This Agreement is governed by English law and the parties submit to the exclusive jurisdiction of the English courts in  relation to any dispute (contractual or non-contractual) concerning this Agreement save that either party may apply to any court for an  injunction or other relief to protect its Intellectual Property Rights.\nSource: 28-pl\nContent: No Waiver. Failure or delay in exercising any right or remedy under this Agreement shall not constitute a waiver of such (or any other)  right or remedy.\n\n11.7 Severability. The invalidity, illegality or unenforceability of any term (or part of a term) of this Agreement shall not affect the continuation  in force of the remainder of the term (if any) and this Agreement.\n\n11.8 No Agency. Except as expressly stated otherwise, nothing in this Agreement shall create an agency, partnership or joint venture of any  kind between the parties.\n\n11.9 No Third-Party Beneficiaries.\nSource: 30-pl\nContent: (b) if Google believes, in good faith, that the Distributor has violated or caused Google to violate any Anti-Bribery Laws (as  defined in Clause 8.5) or that such a violation is reasonably likely to occur,\nSource: 4-pl\n=========\nFINAL ANSWER: This Agreement is governed by English law.\nSOURCES: 28-pl\n\nQUESTION: What did the president say about Michael Jackson?\n=========\nContent: Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.  \n\nLast year COVID-19 kept us apart. This year we are finally together again. \n\nTonight, we meet as Democrats Republicans and Independents. But most importantly as Americans. \n\nWith a duty to one another to the American people to the Constitution. \n\nAnd with an unwavering resolve that freedom will always triumph over tyranny. \n\nSix days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated. \n\nHe thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined. \n\nHe met the Ukrainian people. \n\nFrom President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world. \n\nGroups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers turned soldiers defending their homeland.\nSource: 0-pl\nContent: And we won’t stop. \n\nWe have lost so much to COVID-19. Time with one another. And worst of all, so much loss of life. \n\nLet’s use this moment to reset. Let’s stop looking at COVID-19 as a partisan dividing line and see it for what it is: A God-awful disease.  \n\nLet’s stop seeing each other as enemies, and start seeing each other for who we really are: Fellow Americans.  \n\nWe can’t change how divided we’ve been. But we can change how we move forward—on COVID-19 and other issues we must face together. \n\nI recently visited the New York City Police Department days after the funerals of Officer Wilbert Mora and his partner, Officer Jason Rivera. \n\nThey were responding to a 9-1-1 call when a man shot and killed them with a stolen gun. \n\nOfficer Mora was 27 years old. \n\nOfficer Rivera was 22. \n\nBoth Dominican Americans who’d grown up on the same streets they later chose to patrol as police officers. \n\nI spoke with their families and told them that we are forever in debt for their sacrifice, and we will carry on their mission to restore the trust and safety every community deserves.\nSource: 24-pl\nContent: And ...
#   ]
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [1.93s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "Equivalence partitioning is a testing technique where the input data is divided into partitions, and only one condition from each partition is tested, assuming all conditions in a partition are treated the same by the software. This helps reduce the number of tests needed.\n\nFor example, if a function takes a \"month\" parameter with a valid range of 1 to 12, there are three partitions: x < 1, 1 ≤ x ≤ 12, and 12 < x. Test cases would be chosen to test each partition, such as -2, 5, and 17.\nSOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "Equivalence partitioning is a testing technique where the input data is divided into partitions, and only one condition from each partition is tested, assuming all conditions in a partition are treated the same by the software. This helps reduce the number of tests needed.\n\nFor example, if a function takes a \"month\" parameter with a valid range of 1 to 12, there are three partitions: x < 1, 1 ≤ x ≤ 12, and 12 < x. Test cases would be chosen to test each partition, such as -2, 5, and 17.\nSOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-0ae60f64-b94b-4ba0-9139-3be1e39e9967-0",
#             "usage_metadata": {
#               "input_tokens": 1797,
#               "output_tokens": 148,
#               "total_tokens": 1945,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] [1.93s] Exiting Chain run with output:
# {
#   "text": "Equivalence partitioning is a testing technique where the input data is divided into partitions, and only one condition from each partition is tested, assuming all conditions in a partition are treated the same by the software. This helps reduce the number of tests needed.\n\nFor example, if a function takes a \"month\" parameter with a valid range of 1 to 12, there are three partitions: x < 1, 1 ≤ x ≤ 12, and 12 < x. Test cases would be chosen to test each partition, such as -2, 5, and 17.\nSOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain] [6.27s] Exiting Chain run with output:
# {
#   "output_text": "Equivalence partitioning is a testing technique where the input data is divided into partitions, and only one condition from each partition is tested, assuming all conditions in a partition are treated the same by the software. This helps reduce the number of tests needed.\n\nFor example, if a function takes a \"month\" parameter with a valid range of 1 to 12, there are three partitions: x < 1, 1 ≤ x ≤ 12, and 12 < x. Test cases would be chosen to test each partition, such as -2, 5, and 17.\nSOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain] [6.78s] Exiting Chain run with output:
# {
#   "answer": "Equivalence partitioning is a testing technique where the input data is divided into partitions, and only one condition from each partition is tested, assuming all conditions in a partition are treated the same by the software. This helps reduce the number of tests needed.\n\nFor example, if a function takes a \"month\" parameter with a valid range of 1 to 12, there are three partitions: x < 1, 1 ≤ x ≤ 12, and 12 < x. Test cases would be chosen to test each partition, such as -2, 5, and 17.\n",
#   "sources": "C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf"
# }
# {'answer': 'Equivalence partitioning is a testing technique where the input data is divided into partitions, and only one condition from each partition is tested, assuming all conditions in a partition are treated the same by the software. This helps reduce the number of tests needed.\n\nFor example, if a function takes a "month" parameter with a valid range of 1 to 12, there are three partitions: x < 1, 1 ≤ x ≤ 12, and 12 < x. Test cases would be chosen to test each partition, such as -2, 5, and 17.\n',
#  'sources': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf'}

# %%
image_url="https://storage.googleapis.com/ticket_book_sb_saif/Screenshot%202025-02-17%20103629.png"
extracted_text=extract_text_from_image(image_url)

# %%
query=extracted_text

langchain.debug=True

chain({'question':query},return_only_outputs=True)
# Out:
# [chain/start] [chain:RetrievalQAWithSourcesChain] Entering Chain run with input:
# {
#   "question": "Give me the explanation to\n\npartitioning with example."
# }
# [chain/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain] Entering Chain run with input:
# [inputs]
# [chain/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] Entering Chain run with input:
# {
#   "input_list": [
#     {
#       "context": "IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nEquivalence partitioning \nExample \n• Example of a function which takes a parameter \n“month”.\n• The valid range for the month is 1 to 12, \nrepresenting January to December. This valid \nrange is called a partition.\n• In this example there are two further partitions \nof invalid ranges.\nx < 1 1 ≤ x ≤ 12 12 < x",
#       "question": "Give me the explanation to\n\npartitioning with example."
#     },
#     {
#       "context": "IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nEquivalence partitioning \nExample \n• Test cases are chosen so that each partition \nwould be tested.\nx < 1 1 ≤ x ≤ 12 12 < x\n-2 5 17",
#       "question": "Give me the explanation to\n\npartitioning with example."
#     },
#     {
#       "context": "IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nEquivalence partitions\n• In equivalence-partitioning technique we need \nto test only one condition from each partition. \n– This is because we are assuming that all the \nconditions in one partition will be treated in the \nsame way by the software. \n• Equivalence partitioning is an effective \napproach to testing because it helps to reduce \nthe number of tests.\nRef: Software Engineering, I. Sommerville,  10th Edition",
#       "question": "Give me the explanation to\n\npartitioning with example."
#     },
#     {
#       "context": "IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nPartitioning\n• An activity partition is an activity group for\nactions that have some common characteristic.\n• Partitions often correspond to organizational\nunits or business actors in a business model.",
#       "question": "Give me the explanation to\n\npartitioning with example."
#     }
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nIT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nEquivalence partitioning \nExample \n• Example of a function which takes a parameter \n“month”.\n• The valid range for the month is 1 to 12, \nrepresenting January to December. This valid \nrange is called a partition.\n• In this example there are two further partitions \nof invalid ranges.\nx < 1 1 ≤ x ≤ 12 12 < x\nQuestion: Give me the explanation to\n\npartitioning with example.\nRelevant text, if any:"
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nIT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nEquivalence partitioning \nExample \n• Test cases are chosen so that each partition \nwould be tested.\nx < 1 1 ≤ x ≤ 12 12 < x\n-2 5 17\nQuestion: Give me the explanation to\n\npartitioning with example.\nRelevant text, if any:"
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nIT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nEquivalence partitions\n• In equivalence-partitioning technique we need \nto test only one condition from each partition. \n– This is because we are assuming that all the \nconditions in one partition will be treated in the \nsame way by the software. \n• Equivalence partitioning is an effective \napproach to testing because it helps to reduce \nthe number of tests.\nRef: Software Engineering, I. Sommerville,  10th Edition\nQuestion: Give me the explanation to\n\npartitioning with example.\nRelevant text, if any:"
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nIT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nPartitioning\n• An activity partition is an activity group for\nactions that have some common characteristic.\n• Partitions often correspond to organizational\nunits or business actors in a business model.\nQuestion: Give me the explanation to\n\npartitioning with example.\nRelevant text, if any:"
#   ]
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [3.76s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nEquivalence partitioning \nExample \n• Example of a function which takes a parameter \n“month”.\n• The valid range for the month is 1 to 12, \nrepresenting January to December. This valid \nrange is called a partition.\n• In this example there are two further partitions \nof invalid ranges.\nx < 1 1 ≤ x ≤ 12 12 < x",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nEquivalence partitioning \nExample \n• Example of a function which takes a parameter \n“month”.\n• The valid range for the month is 1 to 12, \nrepresenting January to December. This valid \nrange is called a partition.\n• In this example there are two further partitions \nof invalid ranges.\nx < 1 1 ≤ x ≤ 12 12 < x",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-65ae69b0-c229-4124-a8a6-9899265afa2e-0",
#             "usage_metadata": {
#               "input_tokens": 159,
#               "output_tokens": 108,
#               "total_tokens": 267,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [3.76s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "Equivalence partitioning \nExample \n• Test cases are chosen so that each partition \nwould be tested.\nx < 1 1 ≤ x ≤ 12 12 < x\n-2 5 17",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "Equivalence partitioning \nExample \n• Test cases are chosen so that each partition \nwould be tested.\nx < 1 1 ≤ x ≤ 12 12 < x\n-2 5 17",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-cb24efb7-9c85-4b0f-b8f9-70a5fb307b88-0",
#             "usage_metadata": {
#               "input_tokens": 119,
#               "output_tokens": 50,
#               "total_tokens": 169,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [3.76s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "Equivalence partitions\n• In equivalence-partitioning technique we need \nto test only one condition from each partition. \n– This is because we are assuming that all the \nconditions in one partition will be treated in the \nsame way by the software. \n• Equivalence partitioning is an effective \napproach to testing because it helps to reduce \nthe number of tests.",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "Equivalence partitions\n• In equivalence-partitioning technique we need \nto test only one condition from each partition. \n– This is because we are assuming that all the \nconditions in one partition will be treated in the \nsame way by the software. \n• Equivalence partitioning is an effective \napproach to testing because it helps to reduce \nthe number of tests.",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-18237b68-93b9-44d2-bb84-c15d709863f5-0",
#             "usage_metadata": {
#               "input_tokens": 168,
#               "output_tokens": 82,
#               "total_tokens": 250,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [3.76s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "• An activity partition is an activity group for\nactions that have some common characteristic.\n• Partitions often correspond to organizational\nunits or business actors in a business model.",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "• An activity partition is an activity group for\nactions that have some common characteristic.\n• Partitions often correspond to organizational\nunits or business actors in a business model.",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-00272abb-89c8-42a6-9bc1-49e3407b359c-0",
#             "usage_metadata": {
#               "input_tokens": 108,
#               "output_tokens": 36,
#               "total_tokens": 144,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] [3.76s] Exiting Chain run with output:
# {
#   "outputs": [
#     {
#       "text": "IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nEquivalence partitioning \nExample \n• Example of a function which takes a parameter \n“month”.\n• The valid range for the month is 1 to 12, \nrepresenting January to December. This valid \nrange is called a partition.\n• In this example there are two further partitions \nof invalid ranges.\nx < 1 1 ≤ x ≤ 12 12 < x"
#     },
#     {
#       "text": "Equivalence partitioning \nExample \n• Test cases are chosen so that each partition \nwould be tested.\nx < 1 1 ≤ x ≤ 12 12 < x\n-2 5 17"
#     },
#     {
#       "text": "Equivalence partitions\n• In equivalence-partitioning technique we need \nto test only one condition from each partition. \n– This is because we are assuming that all the \nconditions in one partition will be treated in the \nsame way by the software. \n• Equivalence partitioning is an effective \napproach to testing because it helps to reduce \nthe number of tests."
#     },
#     {
#       "text": "• An activity partition is an activity group for\nactions that have some common characteristic.\n• Partitions often correspond to organizational\nunits or business actors in a business model."
#     }
#   ]
# }
# [chain/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] Entering Chain run with input:
# {
#   "question": "Give me the explanation to\n\npartitioning with example.",
#   "summaries": "Content: IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nEquivalence partitioning \nExample \n• Example of a function which takes a parameter \n“month”.\n• The valid range for the month is 1 to 12, \nrepresenting January to December. This valid \nrange is called a partition.\n• In this example there are two further partitions \nof invalid ranges.\nx < 1 1 ≤ x ≤ 12 12 < x\nSource: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf\n\nContent: Equivalence partitioning \nExample \n• Test cases are chosen so that each partition \nwould be tested.\nx < 1 1 ≤ x ≤ 12 12 < x\n-2 5 17\nSource: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf\n\nContent: Equivalence partitions\n• In equivalence-partitioning technique we need \nto test only one condition from each partition. \n– This is because we are assuming that all the \nconditions in one partition will be treated in the \nsame way by the software. \n• Equivalence partitioning is an effective \napproach to testing because it helps to reduce \nthe number of tests.\nSource: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf\n\nContent: • An activity partition is an activity group for\nactions that have some common characteristic.\n• Partitions often correspond to organizational\nunits or business actors in a business model.\nSource: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf"
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Given the following extracted parts of a long document and a question, create a final answer with references (\"SOURCES\"). \nIf you don't know the answer, just say that you don't know. Don't try to make up an answer.\nALWAYS return a \"SOURCES\" part in your answer.\n\nQUESTION: Which state/country's law governs the interpretation of the contract?\n=========\nContent: This Agreement is governed by English law and the parties submit to the exclusive jurisdiction of the English courts in  relation to any dispute (contractual or non-contractual) concerning this Agreement save that either party may apply to any court for an  injunction or other relief to protect its Intellectual Property Rights.\nSource: 28-pl\nContent: No Waiver. Failure or delay in exercising any right or remedy under this Agreement shall not constitute a waiver of such (or any other)  right or remedy.\n\n11.7 Severability. The invalidity, illegality or unenforceability of any term (or part of a term) of this Agreement shall not affect the continuation  in force of the remainder of the term (if any) and this Agreement.\n\n11.8 No Agency. Except as expressly stated otherwise, nothing in this Agreement shall create an agency, partnership or joint venture of any  kind between the parties.\n\n11.9 No Third-Party Beneficiaries.\nSource: 30-pl\nContent: (b) if Google believes, in good faith, that the Distributor has violated or caused Google to violate any Anti-Bribery Laws (as  defined in Clause 8.5) or that such a violation is reasonably likely to occur,\nSource: 4-pl\n=========\nFINAL ANSWER: This Agreement is governed by English law.\nSOURCES: 28-pl\n\nQUESTION: What did the president say about Michael Jackson?\n=========\nContent: Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.  \n\nLast year COVID-19 kept us apart. This year we are finally together again. \n\nTonight, we meet as Democrats Republicans and Independents. But most importantly as Americans. \n\nWith a duty to one another to the American people to the Constitution. \n\nAnd with an unwavering resolve that freedom will always triumph over tyranny. \n\nSix days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated. \n\nHe thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined. \n\nHe met the Ukrainian people. \n\nFrom President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world. \n\nGroups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers turned soldiers defending their homeland.\nSource: 0-pl\nContent: And we won’t stop. \n\nWe have lost so much to COVID-19. Time with one another. And worst of all, so much loss of life. \n\nLet’s use this moment to reset. Let’s stop looking at COVID-19 as a partisan dividing line and see it for what it is: A God-awful disease.  \n\nLet’s stop seeing each other as enemies, and start seeing each other for who we really are: Fellow Americans.  \n\nWe can’t change how divided we’ve been. But we can change how we move forward—on COVID-19 and other issues we must face together. \n\nI recently visited the New York City Police Department days after the funerals of Officer Wilbert Mora and his partner, Officer Jason Rivera. \n\nThey were responding to a 9-1-1 call when a man shot and killed them with a stolen gun. \n\nOfficer Mora was 27 years old. \n\nOfficer Rivera was 22. \n\nBoth Dominican Americans who’d grown up on the same streets they later chose to patrol as police officers. \n\nI spoke with their families and told them that we are forever in debt for their sacrifice, and we will carry on their mission to restore the trust and safety every community deserves.\nSource: 24-pl\nContent: And ...
#   ]
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [1.90s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "Equivalence partitioning is a testing technique where you divide the input data into partitions. You only need to test one condition from each partition because it is assumed that all conditions in one partition will be treated the same way by the software. For example, if a function takes a \"month\" parameter with a valid range of 1 to 12, there are three partitions: x < 1, 1 ≤ x ≤ 12, and 12 < x. Test cases are chosen so that each partition would be tested (e.g., -2, 5, and 17).\nSOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "Equivalence partitioning is a testing technique where you divide the input data into partitions. You only need to test one condition from each partition because it is assumed that all conditions in one partition will be treated the same way by the software. For example, if a function takes a \"month\" parameter with a valid range of 1 to 12, there are three partitions: x < 1, 1 ≤ x ≤ 12, and 12 < x. Test cases are chosen so that each partition would be tested (e.g., -2, 5, and 17).\nSOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-f4436551-8a94-4974-8cd2-bd7e025309d3-0",
#             "usage_metadata": {
#               "input_tokens": 1815,
#               "output_tokens": 148,
#               "total_tokens": 1963,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] [1.90s] Exiting Chain run with output:
# {
#   "text": "Equivalence partitioning is a testing technique where you divide the input data into partitions. You only need to test one condition from each partition because it is assumed that all conditions in one partition will be treated the same way by the software. For example, if a function takes a \"month\" parameter with a valid range of 1 to 12, there are three partitions: x < 1, 1 ≤ x ≤ 12, and 12 < x. Test cases are chosen so that each partition would be tested (e.g., -2, 5, and 17).\nSOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain] [6.10s] Exiting Chain run with output:
# {
#   "output_text": "Equivalence partitioning is a testing technique where you divide the input data into partitions. You only need to test one condition from each partition because it is assumed that all conditions in one partition will be treated the same way by the software. For example, if a function takes a \"month\" parameter with a valid range of 1 to 12, there are three partitions: x < 1, 1 ≤ x ≤ 12, and 12 < x. Test cases are chosen so that each partition would be tested (e.g., -2, 5, and 17).\nSOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain] [6.60s] Exiting Chain run with output:
# {
#   "answer": "Equivalence partitioning is a testing technique where you divide the input data into partitions. You only need to test one condition from each partition because it is assumed that all conditions in one partition will be treated the same way by the software. For example, if a function takes a \"month\" parameter with a valid range of 1 to 12, there are three partitions: x < 1, 1 ≤ x ≤ 12, and 12 < x. Test cases are chosen so that each partition would be tested (e.g., -2, 5, and 17).\n",
#   "sources": "C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf"
# }
# {'answer': 'Equivalence partitioning is a testing technique where you divide the input data into partitions. You only need to test one condition from each partition because it is assumed that all conditions in one partition will be treated the same way by the software. For example, if a function takes a "month" parameter with a valid range of 1 to 12, there are three partitions: x < 1, 1 ≤ x ≤ 12, and 12 < x. Test cases are chosen so that each partition would be tested (e.g., -2, 5, and 17).\n',
#  'sources': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf'}

# %%
image_path="C:\\Users\\saifu\\Desktop\\rag_project1\\img_hand\WhatsApp Image 2025-02-17 at 12.10.24_6de15b34.jpg"
extracted_text=extract_text_from_image(image_path)
extracted_text
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\saifu\AppData\Local\Temp\ipykernel_24108\3774390661.py:1: SyntaxWarning: invalid escape sequence '\W'
#   image_path="C:\\Users\\saifu\\Desktop\\rag_project1\\img_hand\WhatsApp Image 2025-02-17 at 12.10.24_6de15b34.jpg"
# 'What is boundawy value avaligis 2'

# %%
# The problem is the above tesseract not performing well when using a handwritten Text
# so use a
# 1) LSTM-based OCR - --oem 1
# 2) DL - easyocr
# 3) GoogleVision API

# %%
# 1 --- --oem 1 --psm 6
def extract_handwritten_text(image_path):
    img = Image.open(image_path)
    custom_config = r'--oem 1 --psm 6' 
    text = pytesseract.image_to_string(img, config=custom_config)
    return text.strip()

# %%
image_path="C:\\Users\\saifu\\Desktop\\rag_project1\\img_hand\WhatsApp Image 2025-02-17 at 12.10.23_4f201181.jpg"
extract_text=extract_handwritten_text(image_path)
extract_text
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\saifu\AppData\Local\Temp\ipykernel_19524\615545530.py:1: SyntaxWarning: invalid escape sequence '\W'
#   image_path="C:\\Users\\saifu\\Desktop\\rag_project1\\img_hand\WhatsApp Image 2025-02-17 at 12.10.23_4f201181.jpg"
# 'What js partitioning ?'

# %%
image_path="C:\\Users\\saifu\\Desktop\\rag_project1\\img_hand\WhatsApp Image 2025-02-17 at 12.10.24_6de15b34.jpg"
extract_text=extract_handwritten_text(image_path)
extract_text
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\saifu\AppData\Local\Temp\ipykernel_19524\155276033.py:1: SyntaxWarning: invalid escape sequence '\W'
#   image_path="C:\\Users\\saifu\\Desktop\\rag_project1\\img_hand\WhatsApp Image 2025-02-17 at 12.10.24_6de15b34.jpg"
# '© hab is boamdey value analysts 7'

# %%
#So the --oem 1 --psm 6 also not performing well

# %%
#2 easyocr
# import easyocr
# reader = easyocr.Reader(['en'])
# text = reader.readtext(image_path, detail=0)
# print("Extracted Text:", " ".join(text))
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# The easyocr took too long time so use Google Vison API

# %%
#Google Vision API
import os
import requests
from google.cloud import vision
from google.cloud.vision_v1 import types
from PIL import Image
from io import BytesIO

# %%
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] ="C:\\Users\\saifu\\Desktop\\rag_project1\\09c1a.json"

# %%
client = vision.ImageAnnotatorClient()

# %%
def extract_text_from_image(image_source):
    if image_source.startswith('http'):
        response=requests.get(image_source)
        img=BytesIO(response.content)
        image=vision.Image(content=img.getvalue())
    elif os.path.exists(image_source):
        with open(image_source,'rb') as image_file:
            content=image_file.read()
        image=vision.Image(content=content)
    else:
        raise ValueError("Invalid image source!")

    response=client.text_detection(image=image)
    texts=response.text_annotations

    if texts:
        return texts[0].description.strip()
    return None

# %%
image_path="C:\\Users\\saifu\\Desktop\\rag_project1\\img_hand\WhatsApp Image 2025-02-17 at 12.10.24_6de15b34.jpg"
extract_text=extract_text_from_image(image_path)
extract_text
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\saifu\AppData\Local\Temp\ipykernel_19524\3483860779.py:1: SyntaxWarning: invalid escape sequence '\W'
#   image_path="C:\\Users\\saifu\\Desktop\\rag_project1\\img_hand\WhatsApp Image 2025-02-17 at 12.10.24_6de15b34.jpg"
# 'what is boundary value analysis?'

# %% [markdown]
# so now i am going to use Google visoon api. but comparing to the first option tesseract is better

# %%
image_path="https://storage.googleapis.com/ticket_book_sb_saif/WhatsApp%20Image%202025-02-17%20at%2012.10.23_4f201181.jpg"
extract_text=extract_text_from_image(image_path)

# %%
query=extract_text

langchain.debug=True

chain({'question':query},return_only_outputs=True)
# Out:
# [chain/start] [chain:RetrievalQAWithSourcesChain] Entering Chain run with input:
# {
#   "question": "What is partitioning?"
# }
# [chain/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain] Entering Chain run with input:
# [inputs]
# [chain/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] Entering Chain run with input:
# {
#   "input_list": [
#     {
#       "context": "IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nPartitioning\n• An activity partition is an activity group for\nactions that have some common characteristic.\n• Partitions often correspond to organizational\nunits or business actors in a business model.",
#       "question": "What is partitioning?"
#     },
#     {
#       "context": "IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nEquivalence partitioning \nExample \n• Example of a function which takes a parameter \n“month”.\n• The valid range for the month is 1 to 12, \nrepresenting January to December. This valid \nrange is called a partition.\n• In this example there are two further partitions \nof invalid ranges.\nx < 1 1 ≤ x ≤ 12 12 < x",
#       "question": "What is partitioning?"
#     },
#     {
#       "context": "IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nEquivalence partitions\n• In equivalence-partitioning technique we need \nto test only one condition from each partition. \n– This is because we are assuming that all the \nconditions in one partition will be treated in the \nsame way by the software. \n• Equivalence partitioning is an effective \napproach to testing because it helps to reduce \nthe number of tests.\nRef: Software Engineering, I. Sommerville,  10th Edition",
#       "question": "What is partitioning?"
#     },
#     {
#       "context": "IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nPartitions: SwimLanes\nActivity partition may be shown using\na SwimLane notation:\n• with two, usually parallel lines, either horizontal or\nvertical\n• a name labeling the partition in a box at one end.",
#       "question": "What is partitioning?"
#     }
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nIT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nPartitioning\n• An activity partition is an activity group for\nactions that have some common characteristic.\n• Partitions often correspond to organizational\nunits or business actors in a business model.\nQuestion: What is partitioning?\nRelevant text, if any:"
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nIT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nEquivalence partitioning \nExample \n• Example of a function which takes a parameter \n“month”.\n• The valid range for the month is 1 to 12, \nrepresenting January to December. This valid \nrange is called a partition.\n• In this example there are two further partitions \nof invalid ranges.\nx < 1 1 ≤ x ≤ 12 12 < x\nQuestion: What is partitioning?\nRelevant text, if any:"
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nIT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nEquivalence partitions\n• In equivalence-partitioning technique we need \nto test only one condition from each partition. \n– This is because we are assuming that all the \nconditions in one partition will be treated in the \nsame way by the software. \n• Equivalence partitioning is an effective \napproach to testing because it helps to reduce \nthe number of tests.\nRef: Software Engineering, I. Sommerville,  10th Edition\nQuestion: What is partitioning?\nRelevant text, if any:"
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nIT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nPartitions: SwimLanes\nActivity partition may be shown using\na SwimLane notation:\n• with two, usually parallel lines, either horizontal or\nvertical\n• a name labeling the partition in a box at one end.\nQuestion: What is partitioning?\nRelevant text, if any:"
#   ]
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [4.59s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "• An activity partition is an activity group for\nactions that have some common characteristic.",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "• An activity partition is an activity group for\nactions that have some common characteristic.",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-1dc59e08-dd87-4505-a091-a00a93f7d2d0-0",
#             "usage_metadata": {
#               "input_tokens": 101,
#               "output_tokens": 18,
#               "total_tokens": 119,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [4.59s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "Equivalence partitioning \nExample \n• The valid range for the month is 1 to 12, \nrepresenting January to December. This valid \nrange is called a partition.\n• In this example there are two further partitions \nof invalid ranges.",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "Equivalence partitioning \nExample \n• The valid range for the month is 1 to 12, \nrepresenting January to December. This valid \nrange is called a partition.\n• In this example there are two further partitions \nof invalid ranges.",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-0d08ecc3-7231-42f3-a00e-d7b08b0ce61c-0",
#             "usage_metadata": {
#               "input_tokens": 152,
#               "output_tokens": 57,
#               "total_tokens": 209,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [4.59s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "Equivalence partitions\n• In equivalence-partitioning technique we need \nto test only one condition from each partition. \n– This is because we are assuming that all the \nconditions in one partition will be treated in the \nsame way by the software. \n• Equivalence partitioning is an effective \napproach to testing because it helps to reduce \nthe number of tests.",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "Equivalence partitions\n• In equivalence-partitioning technique we need \nto test only one condition from each partition. \n– This is because we are assuming that all the \nconditions in one partition will be treated in the \nsame way by the software. \n• Equivalence partitioning is an effective \napproach to testing because it helps to reduce \nthe number of tests.",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-bb9f6d02-7bf5-4db1-b0d0-4af602e363ef-0",
#             "usage_metadata": {
#               "input_tokens": 161,
#               "output_tokens": 82,
#               "total_tokens": 243,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [4.59s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "Activity partition may be shown using\na SwimLane notation:\n• with two, usually parallel lines, either horizontal or\nvertical\n• a name labeling the partition in a box at one end.",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "Activity partition may be shown using\na SwimLane notation:\n• with two, usually parallel lines, either horizontal or\nvertical\n• a name labeling the partition in a box at one end.",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-4c7d30fe-d191-4973-8173-bb940aeb3b2d-0",
#             "usage_metadata": {
#               "input_tokens": 109,
#               "output_tokens": 41,
#               "total_tokens": 150,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] [4.59s] Exiting Chain run with output:
# {
#   "outputs": [
#     {
#       "text": "• An activity partition is an activity group for\nactions that have some common characteristic."
#     },
#     {
#       "text": "Equivalence partitioning \nExample \n• The valid range for the month is 1 to 12, \nrepresenting January to December. This valid \nrange is called a partition.\n• In this example there are two further partitions \nof invalid ranges."
#     },
#     {
#       "text": "Equivalence partitions\n• In equivalence-partitioning technique we need \nto test only one condition from each partition. \n– This is because we are assuming that all the \nconditions in one partition will be treated in the \nsame way by the software. \n• Equivalence partitioning is an effective \napproach to testing because it helps to reduce \nthe number of tests."
#     },
#     {
#       "text": "Activity partition may be shown using\na SwimLane notation:\n• with two, usually parallel lines, either horizontal or\nvertical\n• a name labeling the partition in a box at one end."
#     }
#   ]
# }
# [chain/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] Entering Chain run with input:
# {
#   "question": "What is partitioning?",
#   "summaries": "Content: • An activity partition is an activity group for\nactions that have some common characteristic.\nSource: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf\n\nContent: Equivalence partitioning \nExample \n• The valid range for the month is 1 to 12, \nrepresenting January to December. This valid \nrange is called a partition.\n• In this example there are two further partitions \nof invalid ranges.\nSource: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf\n\nContent: Equivalence partitions\n• In equivalence-partitioning technique we need \nto test only one condition from each partition. \n– This is because we are assuming that all the \nconditions in one partition will be treated in the \nsame way by the software. \n• Equivalence partitioning is an effective \napproach to testing because it helps to reduce \nthe number of tests.\nSource: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf\n\nContent: Activity partition may be shown using\na SwimLane notation:\n• with two, usually parallel lines, either horizontal or\nvertical\n• a name labeling the partition in a box at one end.\nSource: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf"
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Given the following extracted parts of a long document and a question, create a final answer with references (\"SOURCES\"). \nIf you don't know the answer, just say that you don't know. Don't try to make up an answer.\nALWAYS return a \"SOURCES\" part in your answer.\n\nQUESTION: Which state/country's law governs the interpretation of the contract?\n=========\nContent: This Agreement is governed by English law and the parties submit to the exclusive jurisdiction of the English courts in  relation to any dispute (contractual or non-contractual) concerning this Agreement save that either party may apply to any court for an  injunction or other relief to protect its Intellectual Property Rights.\nSource: 28-pl\nContent: No Waiver. Failure or delay in exercising any right or remedy under this Agreement shall not constitute a waiver of such (or any other)  right or remedy.\n\n11.7 Severability. The invalidity, illegality or unenforceability of any term (or part of a term) of this Agreement shall not affect the continuation  in force of the remainder of the term (if any) and this Agreement.\n\n11.8 No Agency. Except as expressly stated otherwise, nothing in this Agreement shall create an agency, partnership or joint venture of any  kind between the parties.\n\n11.9 No Third-Party Beneficiaries.\nSource: 30-pl\nContent: (b) if Google believes, in good faith, that the Distributor has violated or caused Google to violate any Anti-Bribery Laws (as  defined in Clause 8.5) or that such a violation is reasonably likely to occur,\nSource: 4-pl\n=========\nFINAL ANSWER: This Agreement is governed by English law.\nSOURCES: 28-pl\n\nQUESTION: What did the president say about Michael Jackson?\n=========\nContent: Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.  \n\nLast year COVID-19 kept us apart. This year we are finally together again. \n\nTonight, we meet as Democrats Republicans and Independents. But most importantly as Americans. \n\nWith a duty to one another to the American people to the Constitution. \n\nAnd with an unwavering resolve that freedom will always triumph over tyranny. \n\nSix days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated. \n\nHe thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined. \n\nHe met the Ukrainian people. \n\nFrom President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world. \n\nGroups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers turned soldiers defending their homeland.\nSource: 0-pl\nContent: And we won’t stop. \n\nWe have lost so much to COVID-19. Time with one another. And worst of all, so much loss of life. \n\nLet’s use this moment to reset. Let’s stop looking at COVID-19 as a partisan dividing line and see it for what it is: A God-awful disease.  \n\nLet’s stop seeing each other as enemies, and start seeing each other for who we really are: Fellow Americans.  \n\nWe can’t change how divided we’ve been. But we can change how we move forward—on COVID-19 and other issues we must face together. \n\nI recently visited the New York City Police Department days after the funerals of Officer Wilbert Mora and his partner, Officer Jason Rivera. \n\nThey were responding to a 9-1-1 call when a man shot and killed them with a stolen gun. \n\nOfficer Mora was 27 years old. \n\nOfficer Rivera was 22. \n\nBoth Dominican Americans who’d grown up on the same streets they later chose to patrol as police officers. \n\nI spoke with their families and told them that we are forever in debt for their sacrifice, and we will carry on their mission to restore the trust and safety every community deserves.\nSource: 24-pl\nContent: And ...
#   ]
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [2.28s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "Partitioning can refer to activity partitioning, which is an activity group for actions that have some common characteristic (SOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf). It can also refer to equivalence partitioning, where a valid range is called a partition, for example, the valid range for the month is 1 to 12 (representing January to December). In equivalence partitioning, you only need to test one condition from each partition because you assume that all the conditions in one partition will be treated the same way by the software (SOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf). Activity partition may be shown using a SwimLane notation (SOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf).\nSOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "Partitioning can refer to activity partitioning, which is an activity group for actions that have some common characteristic (SOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf). It can also refer to equivalence partitioning, where a valid range is called a partition, for example, the valid range for the month is 1 to 12 (representing January to December). In equivalence partitioning, you only need to test one condition from each partition because you assume that all the conditions in one partition will be treated the same way by the software (SOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf). Activity partition may be shown using a SwimLane notation (SOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf).\nSOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-99d7aab8-e255-42b0-9e36-d3f81baa19dd-0",
#             "usage_metadata": {
#               "input_tokens": 1730,
#               "output_tokens": 202,
#               "total_tokens": 1932,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] [2.28s] Exiting Chain run with output:
# {
#   "text": "Partitioning can refer to activity partitioning, which is an activity group for actions that have some common characteristic (SOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf). It can also refer to equivalence partitioning, where a valid range is called a partition, for example, the valid range for the month is 1 to 12 (representing January to December). In equivalence partitioning, you only need to test one condition from each partition because you assume that all the conditions in one partition will be treated the same way by the software (SOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf). Activity partition may be shown using a SwimLane notation (SOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf).\nSOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain] [7.48s] Exiting Chain run with output:
# {
#   "output_text": "Partitioning can refer to activity partitioning, which is an activity group for actions that have some common characteristic (SOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf). It can also refer to equivalence partitioning, where a valid range is called a partition, for example, the valid range for the month is 1 to 12 (representing January to December). In equivalence partitioning, you only need to test one condition from each partition because you assume that all the conditions in one partition will be treated the same way by the software (SOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf). Activity partition may be shown using a SwimLane notation (SOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf).\nSOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain] [8.03s] Exiting Chain run with output:
# {
#   "answer": "Partitioning can refer to activity partitioning, which is an activity group for actions that have some common characteristic (",
#   "sources": "C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf). It can also refer to equivalence partitioning, where a valid range is called a partition, for example, the valid range for the month is 1 to 12 (representing January to December). In equivalence partitioning, you only need to test one condition from each partition because you assume that all the conditions in one partition will be treated the same way by the software ("
# }
# {'answer': 'Partitioning can refer to activity partitioning, which is an activity group for actions that have some common characteristic (',
#  'sources': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf). It can also refer to equivalence partitioning, where a valid range is called a partition, for example, the valid range for the month is 1 to 12 (representing January to December). In equivalence partitioning, you only need to test one condition from each partition because you assume that all the conditions in one partition will be treated the same way by the software ('}

# %%
image_path="https://storage.googleapis.com/ticket_book_sb_saif/00007.png"
extract_text=extract_text_from_image(image_path)

# %%
query=extract_text

langchain.debug=True

chain({'question':query},return_only_outputs=True)
# Out:
# [chain/start] [chain:RetrievalQAWithSourcesChain] Entering Chain run with input:
# {
#   "question": "Briefly explin What is Boundary\nvalue analysis with real world\nexample"
# }
# [chain/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain] Entering Chain run with input:
# [inputs]
# [chain/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] Entering Chain run with input:
# {
#   "input_list": [
#     {
#       "context": "IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\n• Write test cases for input box accepting \nnumbers between 1 and 1000 using Boundary \nvalue analysis\nBoundary Value Analysis\nExample",
#       "question": "Briefly explin What is Boundary\nvalue analysis with real world\nexample"
#     },
#     {
#       "context": "IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nBoundary value analysis\n• Equivalence partitioning is not a stand alone\nmethod to determine test cases. It is usually \nsupplemented by boundary value analysis.\n• Boundary value analysis focuses on values on \nthe edge of an equivalence partition or at the \nsmallest value on either side of an edge.",
#       "question": "Briefly explin What is Boundary\nvalue analysis with real world\nexample"
#     },
#     {
#       "context": "IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nBoundary Value Analysis - Example\n• Test Cases\n– 1: Consider test data exactly as the input \nboundaries of input domain i.e. values 1 and \n1000.\n– 2: Consider test data with values just below the \nextreme edges of input domains i.e. values 0 and \n999.\n– 3: Consider test data with values just above the \nextreme edges of input domain i.e. values 2 and \n1001.",
#       "question": "Briefly explin What is Boundary\nvalue analysis with real world\nexample"
#     },
#     {
#       "context": "a booking is 10. The system interface shows multiple text boxes for the\nuser to enter the needed values.\nWrite 8 Sample test data to check the format and correctness of user-\nentered data to the above system using equivalence partitioning and\nBoundary Value Analysis. Use the Format given below.",
#       "question": "Briefly explin What is Boundary\nvalue analysis with real world\nexample"
#     }
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nIT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\n• Write test cases for input box accepting \nnumbers between 1 and 1000 using Boundary \nvalue analysis\nBoundary Value Analysis\nExample\nQuestion: Briefly explin What is Boundary\nvalue analysis with real world\nexample\nRelevant text, if any:"
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nIT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nBoundary value analysis\n• Equivalence partitioning is not a stand alone\nmethod to determine test cases. It is usually \nsupplemented by boundary value analysis.\n• Boundary value analysis focuses on values on \nthe edge of an equivalence partition or at the \nsmallest value on either side of an edge.\nQuestion: Briefly explin What is Boundary\nvalue analysis with real world\nexample\nRelevant text, if any:"
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\nIT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nBoundary Value Analysis - Example\n• Test Cases\n– 1: Consider test data exactly as the input \nboundaries of input domain i.e. values 1 and \n1000.\n– 2: Consider test data with values just below the \nextreme edges of input domains i.e. values 0 and \n999.\n– 3: Consider test data with values just above the \nextreme edges of input domain i.e. values 2 and \n1001.\nQuestion: Briefly explin What is Boundary\nvalue analysis with real world\nexample\nRelevant text, if any:"
#   ]
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Use the following portion of a long document to see if any of the text is relevant to answer the question. \nReturn any relevant text verbatim.\na booking is 10. The system interface shows multiple text boxes for the\nuser to enter the needed values.\nWrite 8 Sample test data to check the format and correctness of user-\nentered data to the above system using equivalence partitioning and\nBoundary Value Analysis. Use the Format given below.\nQuestion: Briefly explin What is Boundary\nvalue analysis with real world\nexample\nRelevant text, if any:"
#   ]
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [4.19s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\n• Write test cases for input box accepting \nnumbers between 1 and 1000 using Boundary \nvalue analysis\nBoundary Value Analysis\nExample\nQuestion: Briefly explin What is Boundary\nvalue analysis with real world\nexample",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\n• Write test cases for input box accepting \nnumbers between 1 and 1000 using Boundary \nvalue analysis\nBoundary Value Analysis\nExample\nQuestion: Briefly explin What is Boundary\nvalue analysis with real world\nexample",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-bcb5e2ef-b5cb-4b98-8fb8-10cbf0f0f6e1-0",
#             "usage_metadata": {
#               "input_tokens": 105,
#               "output_tokens": 68,
#               "total_tokens": 173,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [4.19s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "Boundary value analysis\n• Boundary value analysis focuses on values on \nthe edge of an equivalence partition or at the \nsmallest value on either side of an edge.",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "Boundary value analysis\n• Boundary value analysis focuses on values on \nthe edge of an equivalence partition or at the \nsmallest value on either side of an edge.",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-36efba0e-ede6-46ef-a0a5-920492d5d672-0",
#             "usage_metadata": {
#               "input_tokens": 136,
#               "output_tokens": 35,
#               "total_tokens": 171,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [4.19s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nBoundary Value Analysis - Example\n• Test Cases\n– 1: Consider test data exactly as the input \nboundaries of input domain i.e. values 1 and \n1000.\n– 2: Consider test data with values just below the \nextreme edges of input domains i.e. values 0 and \n999.\n– 3: Consider test data with values just above the \nextreme edges of input domain i.e. values 2 and \n1001.",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nBoundary Value Analysis - Example\n• Test Cases\n– 1: Consider test data exactly as the input \nboundaries of input domain i.e. values 1 and \n1000.\n– 2: Consider test data with values just below the \nextreme edges of input domains i.e. values 0 and \n999.\n– 3: Consider test data with values just above the \nextreme edges of input domain i.e. values 2 and \n1001.",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-fa3e4250-6a58-4b5a-a9ed-0fc78214e831-0",
#             "usage_metadata": {
#               "input_tokens": 184,
#               "output_tokens": 130,
#               "total_tokens": 314,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [4.19s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "The provided text does not contain an explanation of Boundary Value Analysis or a real-world example. Therefore, there is no relevant text to return.",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "The provided text does not contain an explanation of Boundary Value Analysis or a real-world example. Therefore, there is no relevant text to return.",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-fcfd008b-db6e-433b-9613-38986b4b350a-0",
#             "usage_metadata": {
#               "input_tokens": 117,
#               "output_tokens": 30,
#               "total_tokens": 147,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] [4.19s] Exiting Chain run with output:
# {
#   "outputs": [
#     {
#       "text": "IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\n• Write test cases for input box accepting \nnumbers between 1 and 1000 using Boundary \nvalue analysis\nBoundary Value Analysis\nExample\nQuestion: Briefly explin What is Boundary\nvalue analysis with real world\nexample"
#     },
#     {
#       "text": "Boundary value analysis\n• Boundary value analysis focuses on values on \nthe edge of an equivalence partition or at the \nsmallest value on either side of an edge."
#     },
#     {
#       "text": "IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nBoundary Value Analysis - Example\n• Test Cases\n– 1: Consider test data exactly as the input \nboundaries of input domain i.e. values 1 and \n1000.\n– 2: Consider test data with values just below the \nextreme edges of input domains i.e. values 0 and \n999.\n– 3: Consider test data with values just above the \nextreme edges of input domain i.e. values 2 and \n1001."
#     },
#     {
#       "text": "The provided text does not contain an explanation of Boundary Value Analysis or a real-world example. Therefore, there is no relevant text to return."
#     }
#   ]
# }
# [chain/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] Entering Chain run with input:
# {
#   "question": "Briefly explin What is Boundary\nvalue analysis with real world\nexample",
#   "summaries": "Content: IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\n• Write test cases for input box accepting \nnumbers between 1 and 1000 using Boundary \nvalue analysis\nBoundary Value Analysis\nExample\nQuestion: Briefly explin What is Boundary\nvalue analysis with real world\nexample\nSource: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf\n\nContent: Boundary value analysis\n• Boundary value analysis focuses on values on \nthe edge of an equivalence partition or at the \nsmallest value on either side of an edge.\nSource: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf\n\nContent: IT1060 - Software Process Modeling\nSLIIT  - Faculty of Computing\nBoundary Value Analysis - Example\n• Test Cases\n– 1: Consider test data exactly as the input \nboundaries of input domain i.e. values 1 and \n1000.\n– 2: Consider test data with values just below the \nextreme edges of input domains i.e. values 0 and \n999.\n– 3: Consider test data with values just above the \nextreme edges of input domain i.e. values 2 and \n1001.\nSource: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf\n\nContent: The provided text does not contain an explanation of Boundary Value Analysis or a real-world example. Therefore, there is no relevant text to return.\nSource: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf"
# }
# [llm/start] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: Given the following extracted parts of a long document and a question, create a final answer with references (\"SOURCES\"). \nIf you don't know the answer, just say that you don't know. Don't try to make up an answer.\nALWAYS return a \"SOURCES\" part in your answer.\n\nQUESTION: Which state/country's law governs the interpretation of the contract?\n=========\nContent: This Agreement is governed by English law and the parties submit to the exclusive jurisdiction of the English courts in  relation to any dispute (contractual or non-contractual) concerning this Agreement save that either party may apply to any court for an  injunction or other relief to protect its Intellectual Property Rights.\nSource: 28-pl\nContent: No Waiver. Failure or delay in exercising any right or remedy under this Agreement shall not constitute a waiver of such (or any other)  right or remedy.\n\n11.7 Severability. The invalidity, illegality or unenforceability of any term (or part of a term) of this Agreement shall not affect the continuation  in force of the remainder of the term (if any) and this Agreement.\n\n11.8 No Agency. Except as expressly stated otherwise, nothing in this Agreement shall create an agency, partnership or joint venture of any  kind between the parties.\n\n11.9 No Third-Party Beneficiaries.\nSource: 30-pl\nContent: (b) if Google believes, in good faith, that the Distributor has violated or caused Google to violate any Anti-Bribery Laws (as  defined in Clause 8.5) or that such a violation is reasonably likely to occur,\nSource: 4-pl\n=========\nFINAL ANSWER: This Agreement is governed by English law.\nSOURCES: 28-pl\n\nQUESTION: What did the president say about Michael Jackson?\n=========\nContent: Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.  \n\nLast year COVID-19 kept us apart. This year we are finally together again. \n\nTonight, we meet as Democrats Republicans and Independents. But most importantly as Americans. \n\nWith a duty to one another to the American people to the Constitution. \n\nAnd with an unwavering resolve that freedom will always triumph over tyranny. \n\nSix days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated. \n\nHe thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined. \n\nHe met the Ukrainian people. \n\nFrom President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world. \n\nGroups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers turned soldiers defending their homeland.\nSource: 0-pl\nContent: And we won’t stop. \n\nWe have lost so much to COVID-19. Time with one another. And worst of all, so much loss of life. \n\nLet’s use this moment to reset. Let’s stop looking at COVID-19 as a partisan dividing line and see it for what it is: A God-awful disease.  \n\nLet’s stop seeing each other as enemies, and start seeing each other for who we really are: Fellow Americans.  \n\nWe can’t change how divided we’ve been. But we can change how we move forward—on COVID-19 and other issues we must face together. \n\nI recently visited the New York City Police Department days after the funerals of Officer Wilbert Mora and his partner, Officer Jason Rivera. \n\nThey were responding to a 9-1-1 call when a man shot and killed them with a stolen gun. \n\nOfficer Mora was 27 years old. \n\nOfficer Rivera was 22. \n\nBoth Dominican Americans who’d grown up on the same streets they later chose to patrol as police officers. \n\nI spoke with their families and told them that we are forever in debt for their sacrifice, and we will carry on their mission to restore the trust and safety every community deserves.\nSource: 24-pl\nContent: And ...
#   ]
# }
# [llm/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain > llm:ChatGoogleGenerativeAI] [1.57s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "Boundary Value Analysis focuses on testing values at the edges of input boundaries. For example, when testing an input box that accepts numbers between 1 and 1000, test cases should include the boundary values (1 and 1000), values just below the boundaries (0 and 999), and values just above the boundaries (2 and 1001).\nSOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf",
#         "generation_info": {
#           "finish_reason": "STOP",
#           "safety_ratings": []
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "Boundary Value Analysis focuses on testing values at the edges of input boundaries. For example, when testing an input box that accepts numbers between 1 and 1000, test cases should include the boundary values (1 and 1000), values just below the boundaries (0 and 999), and values just above the boundaries (2 and 1001).\nSOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf",
#             "response_metadata": {
#               "prompt_feedback": {
#                 "block_reason": 0,
#                 "safety_ratings": []
#               },
#               "finish_reason": "STOP",
#               "safety_ratings": []
#             },
#             "type": "ai",
#             "id": "run-331f5449-18fd-4086-a631-8199383a26bd-0",
#             "usage_metadata": {
#               "input_tokens": 1805,
#               "output_tokens": 104,
#               "total_tokens": 1909,
#               "input_token_details": {
#                 "cache_read": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "prompt_feedback": {
#       "block_reason": 0,
#       "safety_ratings": []
#     }
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain > chain:LLMChain] [1.57s] Exiting Chain run with output:
# {
#   "text": "Boundary Value Analysis focuses on testing values at the edges of input boundaries. For example, when testing an input box that accepts numbers between 1 and 1000, test cases should include the boundary values (1 and 1000), values just below the boundaries (0 and 999), and values just above the boundaries (2 and 1001).\nSOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain > chain:MapReduceDocumentsChain] [6.44s] Exiting Chain run with output:
# {
#   "output_text": "Boundary Value Analysis focuses on testing values at the edges of input boundaries. For example, when testing an input box that accepts numbers between 1 and 1000, test cases should include the boundary values (1 and 1000), values just below the boundaries (0 and 999), and values just above the boundaries (2 and 1001).\nSOURCES: C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf"
# }
# [chain/end] [chain:RetrievalQAWithSourcesChain] [7.08s] Exiting Chain run with output:
# {
#   "answer": "Boundary Value Analysis focuses on testing values at the edges of input boundaries. For example, when testing an input box that accepts numbers between 1 and 1000, test cases should include the boundary values (1 and 1000), values just below the boundaries (0 and 999), and values just above the boundaries (2 and 1001).\n",
#   "sources": "C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf"
# }
# {'answer': 'Boundary Value Analysis focuses on testing values at the edges of input boundaries. For example, when testing an input box that accepts numbers between 1 and 1000, test cases should include the boundary values (1 and 1000), values just below the boundaries (0 and 999), and values just above the boundaries (2 and 1001).\n',
#  'sources': 'C:/Users/saifu/Desktop/rag_project1/docs\\SPM - all.pdf'}
